# %%
import numpy as np
import os
import pandas as pd
import shutil

# %%
# List of ROR to exclude from results
excluded_rors = [
    "02n6c9837", # Sanofi
    "01mqmer16", # Hoffmann-La Roche
    "02f9zrr09", # Novartis
    "04r9x1a08", # AstraZeneca
    "00gtmwv55", # Bristol-Myers Squibb
    "03g03ge92"  # Amgen
]

cle_false = "SANS communication\nidentifiée"
cle_true = "AVEC communication\nidentifiée"

LAST_YEAR = 2023

# %%
# Clear previous results
os.system(f"rm -Rf ./../publipostage2")
os.system(f"mkdir -p ./../publipostage2")
# Out:
# 0

# %%
# Load all national data about clinical trials
url = "https://storage.gra.cloud.ovh.net/v1/AUTH_32c5d10cb0fe4519b957064a111717e3/bso_dump/bso-clinical-trials.jsonl.gz"
df = pd.read_json(url, lines=True)

# %%
# Mapping to normalize sponsor name and match to ROR
mapping = pd.read_csv("https://raw.githubusercontent.com/dataesr/bso-clinical-trials/main/bsoclinicaltrials/server/main/bso-lead-sponsors-mapping.csv")

# %%
columns = ["lead_sponsor", "study_completion_year", "NCTId", "eudraCT", "CTIS", "study_type", "status_simplified",
          "acronym", "title", "has_results_or_publications", "has_results_or_publications_within_1y",
          "has_results_or_publications_within_3y", "intervention_type"]
df_interventional = df[df.study_type=="Interventional"]
df_interventional = df_interventional[columns]
df_interventional_completed = df[(df.study_type=="Interventional") & (df.status_simplified=="Completed")]
df_interventional_completed = df_interventional_completed[columns]
df_interventional_academic = df[(df.study_type=="Interventional") & (df.lead_sponsor_type=="academique")]
df_interventional_academic = df_interventional_academic[columns]
df_interventional_completed_academic = df[(df.study_type=="Interventional") & (df.status_simplified=="Completed") & (df.lead_sponsor_type=="academique")]
df_interventional_completed_academic = df_interventional_completed_academic[columns]
dd = pd.merge(df_interventional_completed, mapping, left_on="lead_sponsor", right_on="sponsor", indicator=True, how="inner")
dd_ror = dd[dd.ror.apply(lambda x:isinstance(x, str) and "ror.org/" in x)]
dd_ror.loc[:, "ror_simple"] = dd_ror.ror.apply(lambda x:x.split("/")[-1])
# Out:
# <ipython-input-48-b97ea80328ba>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd_ror.loc[:, "ror_simple"] = dd_ror.ror.apply(lambda x:x.split("/")[-1])

# %%
def get_percent(df_data):
    stats = {"results_last_10_years": {}, "results_last_10_years_drug": {}, "results_within_1_year_last_10_years": {}, "results_within_1_year_last_10_years_drug": {}}
    number_of_trials = len(df_data.index)
    data_results_last_10_years = pd.DataFrame(df_data[(df_data.study_completion_year > LAST_YEAR - 10) & (df_data.study_completion_year <= LAST_YEAR)].has_results_or_publications.value_counts(dropna=False))
    data_results_last_10_years_drug = pd.DataFrame(df_data[(df_data.study_completion_year > LAST_YEAR - 10) & (df_data.study_completion_year <= LAST_YEAR) & (df_data.intervention_type == "DRUG")].has_results_or_publications.value_counts(dropna=False))
    data_results_within_1_year_last_10_years = pd.DataFrame(df_data[(df_data.study_completion_year > LAST_YEAR - 10) & (df_data.study_completion_year <= LAST_YEAR)].has_results_or_publications_within_1y.value_counts(dropna=False))
    data_results_within_1_year_last_10_years_drug = pd.DataFrame(df_data[(df_data.study_completion_year > LAST_YEAR - 10) & (df_data.study_completion_year <= LAST_YEAR) & (df_data.intervention_type == "DRUG")].has_results_or_publications_within_1y.value_counts(dropna=False))
    try:
        stats["results_last_10_years"][cle_true] = data_results_last_10_years[data_results_last_10_years.index==True].values[0][0]
    except Exception as e:
        print(e)
        stats["results_last_10_years"][cle_true] = 0
    try:
        stats["results_last_10_years"][cle_false] = data_results_last_10_years[data_results_last_10_years.index==False].values[0][0]
    except Exception as e:
        print(e)
        stats["results_last_10_years"][cle_false] = 0
    try:
        stats["results_last_10_years_drug"][cle_true] = data_results_last_10_years_drug[data_results_last_10_years_drug.index==True].values[0][0]
    except Exception as e:
        print(e)
        stats["results_last_10_years_drug"][cle_true] = 0
    try:
        stats["results_last_10_years_drug"][cle_false] = data_results_last_10_years_drug[data_results_last_10_years_drug.index==False].values[0][0]
    except Exception as e:
        print(e)
        stats["results_last_10_years_drug"][cle_false] = 0
    try:
        stats["results_within_1_year_last_10_years"][cle_true] = data_results_within_1_year_last_10_years[data_results_within_1_year_last_10_years.index==True].values[0][0]
    except Exception as e:
        print(e)
        stats["results_within_1_year_last_10_years"][cle_true] = 0
    try:
        stats["results_within_1_year_last_10_years"][cle_false] = data_results_within_1_year_last_10_years[data_results_within_1_year_last_10_years.index==False].values[0][0]
    except Exception as e:
        print(e)
        stats["results_within_1_year_last_10_years"][cle_false] = 0
    try:
        stats["results_within_1_year_last_10_years_drug"][cle_true] = data_results_within_1_year_last_10_years_drug[data_results_within_1_year_last_10_years_drug.index==True].values[0][0]
    except Exception as e:
        print(e)
        stats["results_within_1_year_last_10_years_drug"][cle_true] = 0
    try:
        stats["results_within_1_year_last_10_years_drug"][cle_false] = data_results_within_1_year_last_10_years_drug[data_results_within_1_year_last_10_years_drug.index==False].values[0][0]
    except Exception as e:
        print(e)
        stats["results_within_1_year_last_10_years_drug"][cle_false] = 0
    try:
        number_of_trials_last_10_years = stats["results_last_10_years"][cle_false] + stats["results_last_10_years"][cle_true]
        results_last_10_years = int(round(100 * stats["results_last_10_years"][cle_true] / (stats["results_last_10_years"][cle_false] + stats["results_last_10_years"][cle_true]), 0))
        results_last_10_years = f"{results_last_10_years} %"
    except ZeroDivisionError:
        results_last_10_years = np.nan
    try:
        number_of_trials_last_10_years_drug = stats["results_last_10_years_drug"][cle_false] + stats["results_last_10_years_drug"][cle_true]
        results_last_10_years_drug = int(round(100 * stats["results_last_10_years_drug"][cle_true] / (stats["results_last_10_years_drug"][cle_false] + stats["results_last_10_years_drug"][cle_true]), 0))
        results_last_10_years_drug = f"{results_last_10_years_drug} %"
    except ZeroDivisionError:
        results_last_10_years_drug = np.nan
    try:
        number_of_trials_within_1_year_last_10_years = stats["results_within_1_year_last_10_years"][cle_false] + stats["results_within_1_year_last_10_years"][cle_true]
        results_within_1_year_last_10_years = int(round(100 * stats["results_within_1_year_last_10_years"][cle_true] / (stats["results_within_1_year_last_10_years"][cle_false] + stats["results_within_1_year_last_10_years"][cle_true]), 0))
        results_within_1_year_last_10_years = f"{results_within_1_year_last_10_years} %"
    except ZeroDivisionError:
        results_within_1_year_last_10_years = np.nan
    try:
        number_of_trials_within_1_year_last_10_years_drug = stats["results_within_1_year_last_10_years_drug"][cle_false] + stats["results_within_1_year_last_10_years_drug"][cle_true]
        results_within_1_year_last_10_years_drug = int(round(100 * stats["results_within_1_year_last_10_years_drug"][cle_true] / (stats["results_within_1_year_last_10_years_drug"][cle_false] + stats["results_within_1_year_last_10_years_drug"][cle_true]), 0))
        results_within_1_year_last_10_years_drug = f"{results_within_1_year_last_10_years_drug} %"
    except ZeroDivisionError:
        results_within_1_year_last_10_years_drug = np.nan
    return f"{number_of_trials}", f"{number_of_trials_last_10_years}", f"{results_last_10_years}", f"{number_of_trials_last_10_years_drug}", f"{results_last_10_years_drug}", f"{number_of_trials_within_1_year_last_10_years}", f"{results_within_1_year_last_10_years}", f"{number_of_trials_within_1_year_last_10_years_drug}", f"{results_within_1_year_last_10_years_drug}"

# %%
print("france")
indicators_france = get_percent(df_interventional_completed)
print(indicators_france)
print("academique")
indicators_academic = get_percent(df_interventional_completed_academic)
print(indicators_academic)
# Out:
# france
# ('16414', '9608', '51 %', '3629', '77 %', '9608', '33 %', '3629', '55 %')
# academique
# ('6823', '4757', '29 %', '873', '46 %', '4757', '13 %', '873', '20 %')

# %%
dd_perim = pd.merge(df_interventional, mapping, left_on="lead_sponsor", right_on="sponsor", indicator=True, how="inner")
dd_perim_ror = dd_perim[dd_perim.ror.apply(lambda x:isinstance(x, str) and "ror.org/" in x)]
dd_perim_ror["ror_simple"] = dd_perim_ror.ror.apply(lambda x:x.split("/")[-1])
df_perimetre = pd.DataFrame(dd_perim_ror.ror_simple.value_counts()).reset_index()
df_perimetre.columns = ["ror", "nb_interventional_academic"]
df_perimetre = df_perimetre[df_perimetre.ror.apply(lambda x:x not in excluded_rors)]
df_name = dd_perim_ror[["ror_simple", "sponsor_normalized"]].drop_duplicates()
df_perimetre2 = pd.merge(df_perimetre, df_name, left_on="ror", right_on="ror_simple", how="left")
for index, row in df_perimetre2.iterrows():
    df_perimetre2.loc[index, "nb_interventional_academic_completed"] = len(dd_ror[dd_ror["ror_simple"] == row["ror"]])
df_perimetre2["nb_interventional_academic_completed"] = df_perimetre2["nb_interventional_academic_completed"].apply(lambda x:int(x))
df_perimetre2[["ror", "sponsor_normalized", "nb_interventional_academic", "nb_interventional_academic_completed"]].to_csv("../publipostage2/perimetre.csv", index=False)
# Out:
# <ipython-input-51-453dc23dee27>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd_perim_ror["ror_simple"] = dd_perim_ror.ror.apply(lambda x:x.split("/")[-1])

# %%
def get_status_color(row):
    if row.has_results_or_publications is False:
        return "⬛"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is False:
        return "🟥"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is True:
        return "🟧"
    if row.has_results_or_publications_within_1y is True and row.has_results_or_publications_within_3y is True:
        return "🟩"

def get_status(row):
    if row.has_results_or_publications is False:
        return "4"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is False:
        return "3"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is True:
        return "2"
    if row.has_results_or_publications_within_1y is True and row.has_results_or_publications_within_3y is True:
        return "1"

def get_status_name(row):
    if row.has_results_or_publications is False:
        return "4 : pas de résultats postés ni publiés"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is False:
        return "3 : résultats postés ou publiés après les 36 mois"
    if row.has_results_or_publications_within_1y is False and row.has_results_or_publications_within_3y is True:
        return "2 : résultats postés ou publiés entre 12 et 36 mois"
    if row.has_results_or_publications_within_1y is True and row.has_results_or_publications_within_3y is True:
        return "1 : résultats postés ou publiés dans les 12 mois"

# %%
def clean_year(y):
    try:
        return str(int(y))
    except:
        return None

# %%
def make_data(ror):
    os.system(f"mkdir -p ./../publipostage2/{ror}")
    df_tmp = dd_ror[dd_ror.ror_simple == ror].sort_values(by="study_completion_year")
    sponsor_names = pd.DataFrame(df_tmp.lead_sponsor.value_counts()).reset_index()
    sponsor_names.columns = ["variant", "number_of_trials"]
    sponsor_names[["variant"]].to_csv(f"./../publipostage2/{ror}/liste_variantes_noms_{ror}.csv", index=False, header=False)
    df_tmp["status_color"] = df_tmp.apply(lambda row: get_status_color(row), axis=1)
    df_tmp["status"] = df_tmp.apply(lambda row: get_status(row), axis=1)
    df_tmp["status_name"] = df_tmp.apply(lambda row: get_status_name(row), axis=1)
    global_stat = {"ror": ror}
    if len(df_tmp) == 0:
        print(f"No selected clinical trials for {ror}")
        return
    try:
        global_stat["sponsor_name"] = df_tmp.sponsor_normalized.values[0]
    except:
        print("skip " + ror)
        return
    global_stat["sponsor_article"] = "du"
    if global_stat["sponsor_name"][0] in ["A", "E", "I", "O", "U", "Y"]:
        global_stat["sponsor_article"] = "de l'"
    if global_stat["sponsor_name"].split(" ")[0].lower() in ["hospices", "hopitaux", "hôpitaux"]:
        global_stat["sponsor_article"] = "des"
    if global_stat["sponsor_name"].split(" ")[0].lower() in ["hopital", "hôpital"]:
        global_stat["sponsor_article"] = "de l'"
    if global_stat["sponsor_name"].split(" ")[0].lower() in ["clinique"]:
        global_stat["sponsor_article"] = "de la"
    global_stat["number_of_trials"], global_stat["number_of_trials_10_years"], global_stat["indicator_10_years"], global_stat["number_of_trials_10_years_drug"], global_stat["indicator_10_years_drug"], global_stat["number_of_trials_10_years_within_12_months"], global_stat["indicator_10_years_within_12_months"], global_stat["number_of_trials_10_years_within_12_months_drug"], global_stat["indicator_10_years_within_12_months_drug"] = get_percent(df_tmp)
    _, global_stat["number_of_trials_10_years_france"], global_stat["indicator_10_years_france"], global_stat["number_of_trials_10_years_drug_france"], global_stat["indicator_10_years_drug_france"], global_stat["number_of_trials_10_years_within_12_months_france"], global_stat["indicator_10_years_within_12_months_france"], global_stat["number_of_trials_10_years_within_12_months_drug_france"], global_stat["indicator_10_years_within_12_months_drug_france"] = indicators_france
    pd.DataFrame([global_stat]).to_csv(f"./../publipostage2/{ror}/indicators_{ror}.csv", index=False)
    df_tmp["study_completion_year"] = df_tmp["study_completion_year"].apply(lambda x:clean_year(x))
    df_liste_essais_csv = df_tmp[["status_color", "status", "status_name", "NCTId", "eudraCT", "CTIS", "study_completion_year", "title", "acronym",
                                  "intervention_type"]]
    df_liste_essais_csv.columns = ["statut_color", "statut", "statut_name", "NCTId", "eudraCT", "CTIS", "completion_year", "clinical_trial_title",
                                   "acronym", "intervention_type"]
    df_liste_essais_csv.to_csv(f"./../publipostage2/{ror}/liste_essais_cliniques_identifies_{ror}.csv", index=False)
    df_liste_essais_excel = df_tmp[["status", "status_name", "NCTId", "eudraCT", "CTIS", "study_completion_year", "title", "acronym",
                                    "intervention_type"]]
    df_liste_essais_excel.columns = ["statut", "statut_name", "NCTId", "eudraCT", "CTIS", "completion_year", "clinical_trial_title",
                                     "acronym", "intervention_type"]
    df_liste_essais_excel.to_excel(f"./../publipostage2/{ror}/liste_essais_cliniques_identifies_{ror}.xlsx", index=False)
    # excel
    writer = pd.ExcelWriter(f"./../publipostage2/{ror}/liste_essais_cliniques_identifies_{ror}.xlsx") 
    df_liste_essais_excel.to_excel(writer, sheet_name='liste_essais', index=False, na_rep='NaN')
    for column in df_liste_essais_excel:
        column_length = min(max(df_liste_essais_excel[column].astype(str).map(len).max(), len(column)), 40)
        col_idx = df_liste_essais_excel.columns.get_loc(column)
        #print(ror, col_idx, column, column_length)
        writer.sheets['liste_essais'].set_column(col_idx, col_idx, column_length)
    writer.close()  # (writer.save() was deprecated and removed as of 2023/2024)
    
    return global_stat

# %%
global_data = []
rors_to_compute = df_perimetre.ror.to_list()
number_of_trials, number_of_trials_10_years, indicator_10_years, number_of_trials_10_years_drug, indicator_10_years_drug, number_of_trials_10_years_within_12_months, indicator_10_years_within_12_months, number_of_trials_10_years_within_12_months_drug, indicator_10_years_within_12_months_drug = indicators_france
global_data.append({
    "ror": "",
    "sponsor_name": "France",
    "sponsor_article": "",
    "number_of_trials": number_of_trials,
    "number_of_trials_10_years": number_of_trials_10_years,
    "indicator_10_years": indicator_10_years,
    "number_of_trials_10_years_drug": number_of_trials_10_years_drug,
    "indicator_10_years_drug": indicator_10_years_drug,
    "number_of_trials_10_years_within_12_months": number_of_trials_10_years_within_12_months,
    "indicator_10_years_within_12_months": indicator_10_years_within_12_months,
    "number_of_trials_10_years_within_12_months_drug": number_of_trials_10_years_within_12_months_drug,
    "indicator_10_years_within_12_months_drug": indicator_10_years_within_12_months_drug
})
number_of_trials, number_of_trials_10_years, indicator_10_years, number_of_trials_10_years_drug, indicator_10_years_drug, number_of_trials_10_years_within_12_months, indicator_10_years_within_12_months, number_of_trials_10_years_within_12_months_drug, indicator_10_years_within_12_months_drug = indicators_academic
global_data.append({
    "ror": "",
    "sponsor_name": "Promoteurs académiques",
    "sponsor_article": "",
    "number_of_trials": number_of_trials,
    "number_of_trials_10_years": number_of_trials_10_years,
    "indicator_10_years": indicator_10_years,
    "number_of_trials_10_years_drug": number_of_trials_10_years_drug,
    "indicator_10_years_drug": indicator_10_years_drug,
    "number_of_trials_10_years_within_12_months": number_of_trials_10_years_within_12_months,
    "indicator_10_years_within_12_months": indicator_10_years_within_12_months,
    "number_of_trials_10_years_within_12_months_drug": number_of_trials_10_years_within_12_months_drug,
    "indicator_10_years_within_12_months_drug": indicator_10_years_within_12_months_drug
})
for ix, current_ror in enumerate(rors_to_compute):
    if current_ror in excluded_rors:
        continue
    m = make_data(current_ror)
    if m:
        global_data.append({
            "ror": m["ror"],
            "sponsor_name": m["sponsor_name"],
            "sponsor_article": m["sponsor_article"],
            "number_of_trials": m["number_of_trials"],
            "number_of_trials_10_years": m["number_of_trials_10_years"],
            "indicator_10_years": m["indicator_10_years"],
            "number_of_trials_10_years_drug": m["number_of_trials_10_years_drug"],
            "indicator_10_years_drug": m["indicator_10_years_drug"],
            "number_of_trials_10_years_within_12_months": m["number_of_trials_10_years_within_12_months"],
            "indicator_10_years_within_12_months": m["indicator_10_years_within_12_months"],
            "number_of_trials_10_years_within_12_months_drug": m["number_of_trials_10_years_within_12_months_drug"],
            "indicator_10_years_within_12_months_drug": m["indicator_10_years_within_12_months_drug"]
        })
# Write a file to expose the stats for each academic sponsor
pd.DataFrame(global_data).to_csv(f"./../publipostage2/indicators.csv", index=False)
# Out:
# 00pg5jh14 0 statut 6
# 00pg5jh14 1 statut_name 40
# 00pg5jh14 2 NCTId 11
# 00pg5jh14 3 eudraCT 14
# 00pg5jh14 4 CTIS 17
# 00pg5jh14 5 completion_year 15
# 00pg5jh14 6 clinical_trial_title 40
# 00pg5jh14 7 acronym 27
# 00pg5jh14 8 intervention_type 19
# 01502ca60 0 statut 6
# 01502ca60 1 statut_name 40
# 01502ca60 2 NCTId 11
# 01502ca60 3 eudraCT 14
# 01502ca60 4 CTIS 4
# 01502ca60 5 completion_year 15
# 01502ca60 6 clinical_trial_title 40
# 01502ca60 7 acronym 40
# 01502ca60 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# 00mthsf17 0 statut 6
# 00mthsf17 1 statut_name 40
# 00mthsf17 2 NCTId 11
# 00mthsf17 3 eudraCT 14
# 00mthsf17 4 CTIS 4
# 00mthsf17 5 completion_year 15
# 00mthsf17 6 clinical_trial_title 40
# 00mthsf17 7 acronym 27
# 00mthsf17 8 intervention_type 18
# 017h5q109 0 statut 6
# 017h5q109 1 statut_name 40
# 017h5q109 2 NCTId 11
# 017h5q109 3 eudraCT 14
# 017h5q109 4 CTIS 4
# 017h5q109 5 completion_year 15
# 017h5q109 6 clinical_trial_title 40
# 017h5q109 7 acronym 40
# 017h5q109 8 intervention_type 19
# 002cp4060 0 statut 6
# 002cp4060 1 statut_name 40
# 002cp4060 2 NCTId 11
# 002cp4060 3 eudraCT 14
# 002cp4060 4 CTIS 4
# 002cp4060 5 completion_year 15
# 002cp4060 6 clinical_trial_title 40
# 002cp4060 7 acronym 13
# 002cp4060 8 intervention_type 18
# 01hq89f96 0 statut 6
# 01hq89f96 1 statut_name 40
# 01hq89f96 2 NCTId 11
# 01hq89f96 3 eudraCT 14
# 01hq89f96 4 CTIS 4
# 01hq89f96 5 completion_year 15
# 01hq89f96 6 clinical_trial_title 40
# 01hq89f96 7 acronym 31
# 01hq89f96 8 intervention_type 19
# 02tcf7a68 0 statut 6
# 02tcf7a68 1 statut_name 40
# 02tcf7a68 2 NCTId 11
# 02tcf7a68 3 eudraCT 14
# 02tcf7a68 4 CTIS 4
# 02tcf7a68 5 completion_year 15
# 02tcf7a68 6 clinical_trial_title 40
# 02tcf7a68 7 acronym 40
# 02tcf7a68 8 intervention_type 18
# 05c1qsg97 0 statut 6
# 05c1qsg97 1 statut_name 40
# 05c1qsg97 2 NCTId 11
# 05c1qsg97 3 eudraCT 14
# 05c1qsg97 4 CTIS 4
# 05c1qsg97 5 completion_year 15
# 05c1qsg97 6 clinical_trial_title 40
# 05c1qsg97 7 acronym 21
# 05c1qsg97 8 intervention_type 18
# 041rhpw39 0 statut 6
# 041rhpw39 1 statut_name 40
# 041rhpw39 2 NCTId 11
# 041rhpw39 3 eudraCT 14
# 041rhpw39 4 CTIS 4
# 041rhpw39 5 completion_year 15
# 041rhpw39 6 clinical_trial_title 40
# 041rhpw39 7 acronym 30
# 041rhpw39 8 intervention_type 18
# 05qsjq305 0 statut 6
# 05qsjq305 1 statut_name 40
# 05qsjq305 2 NCTId 11
# 05qsjq305 3 eudraCT 14
# 05qsjq305 4 CTIS 4
# 05qsjq305 5 completion_year 15
# 05qsjq305 6 clinical_trial_title 40
# 05qsjq305 7 acronym 17
# 05qsjq305 8 intervention_type 18
# 010567a58 0 statut 6
# 010567a58 1 statut_name 40
# 010567a58 2 NCTId 11
# 010567a58 3 eudraCT 14
# 010567a58 4 CTIS 4
# 010567a58 5 completion_year 15
# 010567a58 6 clinical_trial_title 40
# 010567a58 7 acronym 19
# 010567a58 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# 04bckew43 0 statut 6
# 04bckew43 1 statut_name 40
# 04bckew43 2 NCTId 11
# 04bckew43 3 eudraCT 14
# 04bckew43 4 CTIS 17
# 04bckew43 5 completion_year 15
# 04bckew43 6 clinical_trial_title 40
# 04bckew43 7 acronym 31
# 04bckew43 8 intervention_type 18
# 04pn6vp43 0 statut 6
# 04pn6vp43 1 statut_name 40
# 04pn6vp43 2 NCTId 11
# 04pn6vp43 3 eudraCT 14
# 04pn6vp43 4 CTIS 4
# 04pn6vp43 5 completion_year 15
# 04pn6vp43 6 clinical_trial_title 40
# 04pn6vp43 7 acronym 14
# 04pn6vp43 8 intervention_type 18
# 02ppyfa04 0 statut 6
# 02ppyfa04 1 statut_name 40
# 02ppyfa04 2 NCTId 11
# 02ppyfa04 3 eudraCT 14
# 02ppyfa04 4 CTIS 17
# 02ppyfa04 5 completion_year 15
# 02ppyfa04 6 clinical_trial_title 40
# 02ppyfa04 7 acronym 19
# 02ppyfa04 8 intervention_type 17
# 0321g0743 0 statut 6
# 0321g0743 1 statut_name 40
# 0321g0743 2 NCTId 11
# 0321g0743 3 eudraCT 14
# 0321g0743 4 CTIS 4
# 0321g0743 5 completion_year 15
# 0321g0743 6 clinical_trial_title 40
# 0321g0743 7 acronym 17
# 0321g0743 8 intervention_type 17
# 027arzy69 0 statut 6
# 027arzy69 1 statut_name 40
# 027arzy69 2 NCTId 11
# 027arzy69 3 eudraCT 14
# 027arzy69 4 CTIS 4
# 027arzy69 5 completion_year 15
# 027arzy69 6 clinical_trial_title 40
# 027arzy69 7 acronym 25
# 027arzy69 8 intervention_type 17
# 05qec5a53 0 statut 6
# 05qec5a53 1 statut_name 40
# 05qec5a53 2 NCTId 11
# 05qec5a53 3 eudraCT 14
# 05qec5a53 4 CTIS 4
# 05qec5a53 5 completion_year 15
# 05qec5a53 6 clinical_trial_title 40
# 05qec5a53 7 acronym 29
# 05qec5a53 8 intervention_type 18
# 0084te143 0 statut 6
# 0084te143 1 statut_name 40
# 0084te143 2 NCTId 11
# 0084te143 3 eudraCT 14
# 0084te143 4 CTIS 4
# 0084te143 5 completion_year 15
# 0084te143 6 clinical_trial_title 40
# 0084te143 7 acronym 33
# 0084te143 8 intervention_type 17
# 0250ngj72 0 statut 6
# 0250ngj72 1 statut_name 40
# 0250ngj72 2 NCTId 11
# 0250ngj72 3 eudraCT 14
# 0250ngj72 4 CTIS 4
# 0250ngj72 5 completion_year 15
# 0250ngj72 6 clinical_trial_title 40
# 0250ngj72 7 acronym 27
# 0250ngj72 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# 0275ye937 0 statut 6
# 0275ye937 1 statut_name 40
# 0275ye937 2 NCTId 11
# 0275ye937 3 eudraCT 14
# 0275ye937 4 CTIS 4
# 0275ye937 5 completion_year 15
# 0275ye937 6 clinical_trial_title 40
# 0275ye937 7 acronym 35
# 0275ye937 8 intervention_type 19
# 00cxy0s05 0 statut 6
# 00cxy0s05 1 statut_name 40
# 00cxy0s05 2 NCTId 11
# 00cxy0s05 3 eudraCT 14
# 00cxy0s05 4 CTIS 4
# 00cxy0s05 5 completion_year 15
# 00cxy0s05 6 clinical_trial_title 40
# 00cxy0s05 7 acronym 40
# 00cxy0s05 8 intervention_type 18
# 0377z4z10 0 statut 6
# 0377z4z10 1 statut_name 40
# 0377z4z10 2 NCTId 11
# 0377z4z10 3 eudraCT 14
# 0377z4z10 4 CTIS 17
# 0377z4z10 5 completion_year 15
# 0377z4z10 6 clinical_trial_title 40
# 0377z4z10 7 acronym 14
# 0377z4z10 8 intervention_type 18
# 016ncsr12 0 statut 6
# 016ncsr12 1 statut_name 40
# 016ncsr12 2 NCTId 11
# 016ncsr12 3 eudraCT 14
# 016ncsr12 4 CTIS 4
# 016ncsr12 5 completion_year 15
# 016ncsr12 6 clinical_trial_title 40
# 016ncsr12 7 acronym 19
# 016ncsr12 8 intervention_type 17
# 03evbwn87 0 statut 6
# 03evbwn87 1 statut_name 40
# 03evbwn87 2 NCTId 11
# 03evbwn87 3 eudraCT 14
# 03evbwn87 4 CTIS 17
# 03evbwn87 5 completion_year 15
# 03evbwn87 6 clinical_trial_title 40
# 03evbwn87 7 acronym 21
# 03evbwn87 8 intervention_type 17
# 029s6hd13 0 statut 6
# 029s6hd13 1 statut_name 40
# 029s6hd13 2 NCTId 11
# 029s6hd13 3 eudraCT 14
# 029s6hd13 4 CTIS 4
# 029s6hd13 5 completion_year 15
# 029s6hd13 6 clinical_trial_title 40
# 029s6hd13 7 acronym 14
# 029s6hd13 8 intervention_type 17
# 02vjkv261 0 statut 6
# 02vjkv261 1 statut_name 40
# 02vjkv261 2 NCTId 11
# 02vjkv261 3 eudraCT 14
# 02vjkv261 4 CTIS 4
# 02vjkv261 5 completion_year 15
# 02vjkv261 6 clinical_trial_title 40
# 02vjkv261 7 acronym 36
# 02vjkv261 8 intervention_type 18
# 04vhgtv41 0 statut 6
# 04vhgtv41 1 statut_name 40
# 04vhgtv41 2 NCTId 11
# 04vhgtv41 3 eudraCT 14
# 04vhgtv41 4 CTIS 17
# 04vhgtv41 5 completion_year 15
# 04vhgtv41 6 clinical_trial_title 40
# 04vhgtv41 7 acronym 12
# 04vhgtv41 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# 03pa87f90 0 statut 6
# 03pa87f90 1 statut_name 40
# 03pa87f90 2 NCTId 11
# 03pa87f90 3 eudraCT 14
# 03pa87f90 4 CTIS 17
# 03pa87f90 5 completion_year 15
# 03pa87f90 6 clinical_trial_title 40
# 03pa87f90 7 acronym 34
# 03pa87f90 8 intervention_type 19
# index 0 is out of bounds for axis 0 with size 0
# 058td2q88 0 statut 6
# 058td2q88 1 statut_name 40
# 058td2q88 2 NCTId 11
# 058td2q88 3 eudraCT 14
# 058td2q88 4 CTIS 4
# 058td2q88 5 completion_year 15
# 058td2q88 6 clinical_trial_title 40
# 058td2q88 7 acronym 14
# 058td2q88 8 intervention_type 19
# 01kv58h76 0 statut 6
# 01kv58h76 1 statut_name 40
# 01kv58h76 2 NCTId 11
# 01kv58h76 3 eudraCT 14
# 01kv58h76 4 CTIS 4
# 01kv58h76 5 completion_year 15
# 01kv58h76 6 clinical_trial_title 40
# 01kv58h76 7 acronym 21
# 01kv58h76 8 intervention_type 17
# 01cmnjq37 0 statut 6
# 01cmnjq37 1 statut_name 40
# 01cmnjq37 2 NCTId 11
# 01cmnjq37 3 eudraCT 14
# 01cmnjq37 4 CTIS 17
# 01cmnjq37 5 completion_year 15
# 01cmnjq37 6 clinical_trial_title 40
# 01cmnjq37 7 acronym 31
# 01cmnjq37 8 intervention_type 17
# 00jpq0w62 0 statut 6
# 00jpq0w62 1 statut_name 40
# 00jpq0w62 2 NCTId 11
# 00jpq0w62 3 eudraCT 14
# 00jpq0w62 4 CTIS 4
# 00jpq0w62 5 completion_year 15
# 00jpq0w62 6 clinical_trial_title 40
# 00jpq0w62 7 acronym 16
# 00jpq0w62 8 intervention_type 18
# 01tc2d264 0 statut 6
# 01tc2d264 1 statut_name 40
# 01tc2d264 2 NCTId 11
# 01tc2d264 3 eudraCT 14
# 01tc2d264 4 CTIS 4
# 01tc2d264 5 completion_year 15
# 01tc2d264 6 clinical_trial_title 40
# 01tc2d264 7 acronym 40
# 01tc2d264 8 intervention_type 19
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 01jbb3w63 0 statut 6
# 01jbb3w63 1 statut_name 40
# 01jbb3w63 2 NCTId 11
# 01jbb3w63 3 eudraCT 14
# 01jbb3w63 4 CTIS 4
# 01jbb3w63 5 completion_year 15
# 01jbb3w63 6 clinical_trial_title 40
# 01jbb3w63 7 acronym 40
# 01jbb3w63 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# 03capj968 0 statut 6
# 03capj968 1 statut_name 40
# 03capj968 2 NCTId 11
# 03capj968 3 eudraCT 14
# 03capj968 4 CTIS 17
# 03capj968 5 completion_year 15
# 03capj968 6 clinical_trial_title 40
# 03capj968 7 acronym 31
# 03capj968 8 intervention_type 19
# 04t0gwh46 0 statut 6
# 04t0gwh46 1 statut_name 40
# 04t0gwh46 2 NCTId 11
# 04t0gwh46 3 eudraCT 14
# 04t0gwh46 4 CTIS 4
# 04t0gwh46 5 completion_year 15
# 04t0gwh46 6 clinical_trial_title 40
# 04t0gwh46 7 acronym 14
# 04t0gwh46 8 intervention_type 17
# 03xfq7a50 0 statut 6
# 03xfq7a50 1 statut_name 40
# 03xfq7a50 2 NCTId 11
# 03xfq7a50 3 eudraCT 14
# 03xfq7a50 4 CTIS 4
# 03xfq7a50 5 completion_year 15
# 03xfq7a50 6 clinical_trial_title 40
# 03xfq7a50 7 acronym 12
# 03xfq7a50 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04s3t1g37 0 statut 6
# 04s3t1g37 1 statut_name 40
# 04s3t1g37 2 NCTId 11
# 04s3t1g37 3 eudraCT 14
# 04s3t1g37 4 CTIS 4
# 04s3t1g37 5 completion_year 15
# 04s3t1g37 6 clinical_trial_title 40
# 04s3t1g37 7 acronym 17
# 04s3t1g37 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 046bx1082 0 statut 6
# 046bx1082 1 statut_name 40
# 046bx1082 2 NCTId 11
# 046bx1082 3 eudraCT 7
# 046bx1082 4 CTIS 4
# 046bx1082 5 completion_year 15
# 046bx1082 6 clinical_trial_title 40
# 046bx1082 7 acronym 12
# 046bx1082 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02mdxv534 0 statut 6
# 02mdxv534 1 statut_name 40
# 02mdxv534 2 NCTId 11
# 02mdxv534 3 eudraCT 14
# 02mdxv534 4 CTIS 4
# 02mdxv534 5 completion_year 15
# 02mdxv534 6 clinical_trial_title 40
# 02mdxv534 7 acronym 40
# 02mdxv534 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# 04yvax419 0 statut 6
# 04yvax419 1 statut_name 40
# 04yvax419 2 NCTId 11
# 04yvax419 3 eudraCT 14
# 04yvax419 4 CTIS 4
# 04yvax419 5 completion_year 15
# 04yvax419 6 clinical_trial_title 40
# 04yvax419 7 acronym 19
# 04yvax419 8 intervention_type 17
# 02yw1f353 0 statut 6
# 02yw1f353 1 statut_name 40
# 02yw1f353 2 NCTId 11
# 02yw1f353 3 eudraCT 14
# 02yw1f353 4 CTIS 4
# 02yw1f353 5 completion_year 15
# 02yw1f353 6 clinical_trial_title 40
# 02yw1f353 7 acronym 15
# 02yw1f353 8 intervention_type 17
# 02x9y0j10 0 statut 6
# 02x9y0j10 1 statut_name 40
# 02x9y0j10 2 NCTId 11
# 02x9y0j10 3 eudraCT 14
# 02x9y0j10 4 CTIS 4
# 02x9y0j10 5 completion_year 15
# 02x9y0j10 6 clinical_trial_title 40
# 02x9y0j10 7 acronym 12
# 02x9y0j10 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04c3yce28 0 statut 6
# 04c3yce28 1 statut_name 40
# 04c3yce28 2 NCTId 11
# 04c3yce28 3 eudraCT 7
# 04c3yce28 4 CTIS 4
# 04c3yce28 5 completion_year 15
# 04c3yce28 6 clinical_trial_title 40
# 04c3yce28 7 acronym 10
# 04c3yce28 8 intervention_type 17
# 01m6as704 0 statut 6
# 01m6as704 1 statut_name 40
# 01m6as704 2 NCTId 11
# 01m6as704 3 eudraCT 14
# 01m6as704 4 CTIS 4
# 01m6as704 5 completion_year 15
# 01m6as704 6 clinical_trial_title 40
# 01m6as704 7 acronym 13
# 01m6as704 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# 05epqd940 0 statut 6
# 05epqd940 1 statut_name 40
# 05epqd940 2 NCTId 11
# 05epqd940 3 eudraCT 14
# 05epqd940 4 CTIS 4
# 05epqd940 5 completion_year 15
# 05epqd940 6 clinical_trial_title 40
# 05epqd940 7 acronym 12
# 05epqd940 8 intervention_type 17
# 02kxjxy06 0 statut 6
# 02kxjxy06 1 statut_name 40
# 02kxjxy06 2 NCTId 11
# 02kxjxy06 3 eudraCT 14
# 02kxjxy06 4 CTIS 4
# 02kxjxy06 5 completion_year 15
# 02kxjxy06 6 clinical_trial_title 40
# 02kxjxy06 7 acronym 17
# 02kxjxy06 8 intervention_type 17
# 04n1nkp35 0 statut 6
# 04n1nkp35 1 statut_name 40
# 04n1nkp35 2 NCTId 11
# 04n1nkp35 3 eudraCT 14
# 04n1nkp35 4 CTIS 4
# 04n1nkp35 5 completion_year 15
# 04n1nkp35 6 clinical_trial_title 40
# 04n1nkp35 7 acronym 11
# 04n1nkp35 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# 004dan487 0 statut 6
# 004dan487 1 statut_name 40
# 004dan487 2 NCTId 11
# 004dan487 3 eudraCT 14
# 004dan487 4 CTIS 4
# 004dan487 5 completion_year 15
# 004dan487 6 clinical_trial_title 40
# 004dan487 7 acronym 12
# 004dan487 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 025s1b152 0 statut 6
# 025s1b152 1 statut_name 38
# 025s1b152 2 NCTId 11
# 025s1b152 3 eudraCT 7
# 025s1b152 4 CTIS 4
# 025s1b152 5 completion_year 15
# 025s1b152 6 clinical_trial_title 40
# 025s1b152 7 acronym 10
# 025s1b152 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 053evvt91 0 statut 6
# 053evvt91 1 statut_name 40
# 053evvt91 2 NCTId 11
# 053evvt91 3 eudraCT 14
# 053evvt91 4 CTIS 4
# 053evvt91 5 completion_year 15
# 053evvt91 6 clinical_trial_title 40
# 053evvt91 7 acronym 13
# 053evvt91 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04cfjax51 0 statut 6
# 04cfjax51 1 statut_name 40
# 04cfjax51 2 NCTId 11
# 04cfjax51 3 eudraCT 14
# 04cfjax51 4 CTIS 4
# 04cfjax51 5 completion_year 15
# 04cfjax51 6 clinical_trial_title 40
# 04cfjax51 7 acronym 40
# 04cfjax51 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 0495fxg12 0 statut 6
# 0495fxg12 1 statut_name 40
# 0495fxg12 2 NCTId 11
# 0495fxg12 3 eudraCT 14
# 0495fxg12 4 CTIS 4
# 0495fxg12 5 completion_year 15
# 0495fxg12 6 clinical_trial_title 40
# 0495fxg12 7 acronym 13
# 0495fxg12 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 0103yxp25 0 statut 6
# 0103yxp25 1 statut_name 40
# 0103yxp25 2 NCTId 11
# 0103yxp25 3 eudraCT 14
# 0103yxp25 4 CTIS 4
# 0103yxp25 5 completion_year 15
# 0103yxp25 6 clinical_trial_title 40
# 0103yxp25 7 acronym 12
# 0103yxp25 8 intervention_type 17
# 047wq3n50 0 statut 6
# 047wq3n50 1 statut_name 40
# 047wq3n50 2 NCTId 11
# 047wq3n50 3 eudraCT 14
# 047wq3n50 4 CTIS 4
# 047wq3n50 5 completion_year 15
# 047wq3n50 6 clinical_trial_title 40
# 047wq3n50 7 acronym 13
# 047wq3n50 8 intervention_type 19
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02d741577 0 statut 6
# 02d741577 1 statut_name 40
# 02d741577 2 NCTId 11
# 02d741577 3 eudraCT 14
# 02d741577 4 CTIS 4
# 02d741577 5 completion_year 15
# 02d741577 6 clinical_trial_title 40
# 02d741577 7 acronym 21
# 02d741577 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 003vg9w96 0 statut 6
# 003vg9w96 1 statut_name 40
# 003vg9w96 2 NCTId 11
# 003vg9w96 3 eudraCT 7
# 003vg9w96 4 CTIS 4
# 003vg9w96 5 completion_year 15
# 003vg9w96 6 clinical_trial_title 40
# 003vg9w96 7 acronym 13
# 003vg9w96 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 0376kfa34 0 statut 6
# 0376kfa34 1 statut_name 40
# 0376kfa34 2 NCTId 11
# 0376kfa34 3 eudraCT 7
# 0376kfa34 4 CTIS 4
# 0376kfa34 5 completion_year 15
# 0376kfa34 6 clinical_trial_title 40
# 0376kfa34 7 acronym 11
# 0376kfa34 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04wqvjr21 0 statut 6
# 04wqvjr21 1 statut_name 40
# 04wqvjr21 2 NCTId 11
# 04wqvjr21 3 eudraCT 7
# 04wqvjr21 4 CTIS 4
# 04wqvjr21 5 completion_year 15
# 04wqvjr21 6 clinical_trial_title 40
# 04wqvjr21 7 acronym 12
# 04wqvjr21 8 intervention_type 19
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03bf2nz41 0 statut 6
# 03bf2nz41 1 statut_name 40
# 03bf2nz41 2 NCTId 11
# 03bf2nz41 3 eudraCT 7
# 03bf2nz41 4 CTIS 4
# 03bf2nz41 5 completion_year 15
# 03bf2nz41 6 clinical_trial_title 40
# 03bf2nz41 7 acronym 9
# 03bf2nz41 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 05k9skc85 0 statut 6
# 05k9skc85 1 statut_name 38
# 05k9skc85 2 NCTId 11
# 05k9skc85 3 eudraCT 14
# 05k9skc85 4 CTIS 4
# 05k9skc85 5 completion_year 15
# 05k9skc85 6 clinical_trial_title 40
# 05k9skc85 7 acronym 14
# 05k9skc85 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03ytpa045 0 statut 6
# 03ytpa045 1 statut_name 38
# 03ytpa045 2 NCTId 11
# 03ytpa045 3 eudraCT 7
# 03ytpa045 4 CTIS 4
# 03ytpa045 5 completion_year 15
# 03ytpa045 6 clinical_trial_title 40
# 03ytpa045 7 acronym 10
# 03ytpa045 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 0219xsk19 0 statut 6
# 0219xsk19 1 statut_name 38
# 0219xsk19 2 NCTId 11
# 0219xsk19 3 eudraCT 14
# 0219xsk19 4 CTIS 4
# 0219xsk19 5 completion_year 15
# 0219xsk19 6 clinical_trial_title 40
# 0219xsk19 7 acronym 21
# 0219xsk19 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 029brtt94 0 statut 6
# 029brtt94 1 statut_name 40
# 029brtt94 2 NCTId 11
# 029brtt94 3 eudraCT 7
# 029brtt94 4 CTIS 4
# 029brtt94 5 completion_year 15
# 029brtt94 6 clinical_trial_title 40
# 029brtt94 7 acronym 12
# 029brtt94 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 054jcxz87 0 statut 6
# 054jcxz87 1 statut_name 38
# 054jcxz87 2 NCTId 11
# 054jcxz87 3 eudraCT 7
# 054jcxz87 4 CTIS 4
# 054jcxz87 5 completion_year 15
# 054jcxz87 6 clinical_trial_title 40
# 054jcxz87 7 acronym 9
# 054jcxz87 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03mkjjy25 0 statut 6
# 03mkjjy25 1 statut_name 40
# 03mkjjy25 2 NCTId 11
# 03mkjjy25 3 eudraCT 7
# 03mkjjy25 4 CTIS 4
# 03mkjjy25 5 completion_year 15
# 03mkjjy25 6 clinical_trial_title 40
# 03mkjjy25 7 acronym 8
# 03mkjjy25 8 intervention_type 17
# No selected clinical trials for 02xnj2427
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 01tfhsg94 0 statut 6
# 01tfhsg94 1 statut_name 40
# 01tfhsg94 2 NCTId 11
# 01tfhsg94 3 eudraCT 7
# 01tfhsg94 4 CTIS 4
# 01tfhsg94 5 completion_year 15
# 01tfhsg94 6 clinical_trial_title 40
# 01tfhsg94 7 acronym 10
# 01tfhsg94 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 01zwdgr60 0 statut 6
# 01zwdgr60 1 statut_name 40
# 01zwdgr60 2 NCTId 11
# 01zwdgr60 3 eudraCT 7
# 01zwdgr60 4 CTIS 4
# 01zwdgr60 5 completion_year 15
# 01zwdgr60 6 clinical_trial_title 40
# 01zwdgr60 7 acronym 8
# 01zwdgr60 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 05f82e368 0 statut 6
# 05f82e368 1 statut_name 40
# 05f82e368 2 NCTId 11
# 05f82e368 3 eudraCT 7
# 05f82e368 4 CTIS 4
# 05f82e368 5 completion_year 15
# 05f82e368 6 clinical_trial_title 40
# 05f82e368 7 acronym 11
# 05f82e368 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03deam493 0 statut 6
# 03deam493 1 statut_name 40
# 03deam493 2 NCTId 11
# 03deam493 3 eudraCT 14
# 03deam493 4 CTIS 4
# 03deam493 5 completion_year 15
# 03deam493 6 clinical_trial_title 40
# 03deam493 7 acronym 11
# 03deam493 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04q33ey84 0 statut 6
# 04q33ey84 1 statut_name 38
# 04q33ey84 2 NCTId 11
# 04q33ey84 3 eudraCT 7
# 04q33ey84 4 CTIS 4
# 04q33ey84 5 completion_year 15
# 04q33ey84 6 clinical_trial_title 40
# 04q33ey84 7 acronym 13
# 04q33ey84 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02pve7657 0 statut 6
# 02pve7657 1 statut_name 40
# 02pve7657 2 NCTId 11
# 02pve7657 3 eudraCT 7
# 02pve7657 4 CTIS 4
# 02pve7657 5 completion_year 15
# 02pve7657 6 clinical_trial_title 40
# 02pve7657 7 acronym 13
# 02pve7657 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02carhc19 0 statut 6
# 02carhc19 1 statut_name 40
# 02carhc19 2 NCTId 11
# 02carhc19 3 eudraCT 7
# 02carhc19 4 CTIS 4
# 02carhc19 5 completion_year 15
# 02carhc19 6 clinical_trial_title 40
# 02carhc19 7 acronym 13
# 02carhc19 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 01r35jx22 0 statut 6
# 01r35jx22 1 statut_name 40
# 01r35jx22 2 NCTId 11
# 01r35jx22 3 eudraCT 7
# 01r35jx22 4 CTIS 4
# 01r35jx22 5 completion_year 15
# 01r35jx22 6 clinical_trial_title 40
# 01r35jx22 7 acronym 14
# 01r35jx22 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03vn1xq77 0 statut 6
# 03vn1xq77 1 statut_name 40
# 03vn1xq77 2 NCTId 11
# 03vn1xq77 3 eudraCT 7
# 03vn1xq77 4 CTIS 4
# 03vn1xq77 5 completion_year 15
# 03vn1xq77 6 clinical_trial_title 40
# 03vn1xq77 7 acronym 12
# 03vn1xq77 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 024v1ns19 0 statut 6
# 024v1ns19 1 statut_name 38
# 024v1ns19 2 NCTId 11
# 024v1ns19 3 eudraCT 7
# 024v1ns19 4 CTIS 4
# 024v1ns19 5 completion_year 15
# 024v1ns19 6 clinical_trial_title 40
# 024v1ns19 7 acronym 7
# 024v1ns19 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03s4khd80 0 statut 6
# 03s4khd80 1 statut_name 40
# 03s4khd80 2 NCTId 11
# 03s4khd80 3 eudraCT 14
# 03s4khd80 4 CTIS 4
# 03s4khd80 5 completion_year 15
# 03s4khd80 6 clinical_trial_title 40
# 03s4khd80 7 acronym 15
# 03s4khd80 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 0246mbd04 0 statut 6
# 0246mbd04 1 statut_name 38
# 0246mbd04 2 NCTId 11
# 0246mbd04 3 eudraCT 7
# 0246mbd04 4 CTIS 4
# 0246mbd04 5 completion_year 15
# 0246mbd04 6 clinical_trial_title 40
# 0246mbd04 7 acronym 12
# 0246mbd04 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02qxa1v47 0 statut 6
# 02qxa1v47 1 statut_name 40
# 02qxa1v47 2 NCTId 11
# 02qxa1v47 3 eudraCT 7
# 02qxa1v47 4 CTIS 4
# 02qxa1v47 5 completion_year 15
# 02qxa1v47 6 clinical_trial_title 40
# 02qxa1v47 7 acronym 9
# 02qxa1v47 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04vfs2w97 0 statut 6
# 04vfs2w97 1 statut_name 40
# 04vfs2w97 2 NCTId 11
# 04vfs2w97 3 eudraCT 7
# 04vfs2w97 4 CTIS 4
# 04vfs2w97 5 completion_year 15
# 04vfs2w97 6 clinical_trial_title 40
# 04vfs2w97 7 acronym 9
# 04vfs2w97 8 intervention_type 17
# No selected clinical trials for 03wr2ty35
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 057qpr032 0 statut 6
# 057qpr032 1 statut_name 40
# 057qpr032 2 NCTId 11
# 057qpr032 3 eudraCT 7
# 057qpr032 4 CTIS 4
# 057qpr032 5 completion_year 15
# 057qpr032 6 clinical_trial_title 40
# 057qpr032 7 acronym 9
# 057qpr032 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 02en5vm52 0 statut 6
# 02en5vm52 1 statut_name 40
# 02en5vm52 2 NCTId 11
# 02en5vm52 3 eudraCT 7
# 02en5vm52 4 CTIS 4
# 02en5vm52 5 completion_year 15
# 02en5vm52 6 clinical_trial_title 40
# 02en5vm52 7 acronym 12
# 02en5vm52 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03er61e50 0 statut 6
# 03er61e50 1 statut_name 40
# 03er61e50 2 NCTId 11
# 03er61e50 3 eudraCT 7
# 03er61e50 4 CTIS 4
# 03er61e50 5 completion_year 15
# 03er61e50 6 clinical_trial_title 40
# 03er61e50 7 acronym 7
# 03er61e50 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 03hypw319 0 statut 6
# 03hypw319 1 statut_name 38
# 03hypw319 2 NCTId 11
# 03hypw319 3 eudraCT 7
# 03hypw319 4 CTIS 4
# 03hypw319 5 completion_year 15
# 03hypw319 6 clinical_trial_title 40
# 03hypw319 7 acronym 7
# 03hypw319 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 035xkbk20 0 statut 6
# 035xkbk20 1 statut_name 38
# 035xkbk20 2 NCTId 11
# 035xkbk20 3 eudraCT 7
# 035xkbk20 4 CTIS 4
# 035xkbk20 5 completion_year 15
# 035xkbk20 6 clinical_trial_title 40
# 035xkbk20 7 acronym 7
# 035xkbk20 8 intervention_type 18
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 044t4x544 0 statut 6
# 044t4x544 1 statut_name 40
# 044t4x544 2 NCTId 11
# 044t4x544 3 eudraCT 7
# 044t4x544 4 CTIS 4
# 044t4x544 5 completion_year 15
# 044t4x544 6 clinical_trial_title 40
# 044t4x544 7 acronym 7
# 044t4x544 8 intervention_type 17
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# index 0 is out of bounds for axis 0 with size 0
# 04xhy8q59 0 statut 6
# 04xhy8q59 1 statut_name 38
# 04xhy8q59 2 NCTId 11
# 04xhy8q59 3 eudraCT 7
# 04xhy8q59 4 CTIS 4
# 04xhy8q59 5 completion_year 15
# 04xhy8q59 6 clinical_trial_title 40
# 04xhy8q59 7 acronym 12
# 04xhy8q59 8 intervention_type 17
# No selected clinical trials for 051kpcy16
# No selected clinical trials for 02v6kpv12
# No selected clinical trials for 0199hds37
# No selected clinical trials for 051escj72
# No selected clinical trials for 03nhjew95

# %%
shutil.make_archive('./../publipostage2', 'zip', './../publipostage2')
# Out:
# '/Users/eric/MESRI/bso-clinical-trials/publipostage2.zip'
