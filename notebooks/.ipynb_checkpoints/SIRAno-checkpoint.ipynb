# %%
import pandas as pd
url = "https://www.data.gouv.fr/fr/datasets/r/c156ce7f-1ec8-4381-b8b9-fe5d2f933168"
df = pd.read_csv(url, sep=';', encoding='iso-8859-1')

# %%
sirano_dict = {}
for ix, row in df.iterrows():
    if isinstance(row.numero_registre_essais, str):
        nct = row.numero_registre_essais
        if nct not in sirano_dict:
            sirano_dict[nct] = {'financement_total': 0.0, 'financements':[]}
        sirano_dict[nct]['financements'].append(row.to_dict())
        if isinstance(row.financement_total, float) or isinstance(row.financement_total, int):
            sirano_dict[nct]['financement_total'] += row.financement_total

# %%
# Out:
# 1611 essais dans SIRANo

# %%
print(f'{len(sirano_dict)} essais dans SIRANo')

# %%
sirano_dict
# Out:
# {'NCT02611440': {'financement_total': 215630.0,
#   'financements': [{'appel_a_projets': 'PREPS',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ADMED AVC',
#     'titre': "Impact d'une intervention pluriprofessionnelle visant à améliorer l'ADhésion MEDicamenteuse (prévention secondaire cardio-neuro-vasculaire) chez les patients ayant présenté un Accident Vasculaire Cérébral Ischémique.",
#     'discipline_principale': 'médecine physique et réadaptation',
#     'nom_porteur': 'RODE',
#     'prenom_porteur': 'Gilles',
#     'financement_total': 215630.0,
#     'numero_registre_essais': 'NCT02611440',
#     'numero_tranche': '3'}]},
#  'NCT02895230': {'financement_total': 79784.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU RENNES',
#     'finess': 350005179,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ADTCR',
#     'titre': 'Suppression androgénique et risque cardiovasculaire',
#     'discipline_principale': 'pharmacologie',
#     'nom_porteur': 'OGER',
#     'prenom_porteur': 'Emmanuel',
#     'financement_total': 79784.0,
#     'numero_registre_essais': 'NCT02895230',
#     'numero_tranche': '5'}]},
#  'NCT02534974': {'financement_total': 469915.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CENTRE HOSP. UNIVERSITAIRE DE POITIERS',
#     'finess': 860014208,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'AGATE',
#     'titre': "Impact de l'ajout d'un dispositif de régulation pneumatique continue de la pression du ballonnet à une stratégie globale de prévention des pneumonies acquises sous ventilation mécanique chez le traumatisé grave. Etude multicentrique, randomisée contrôlée.",
#     'discipline_principale': 'anesthésiologie / réanimation',
#     'nom_porteur': 'MIMOZ',
#     'prenom_porteur': 'Olivier',
#     'financement_total': 469915.0,
#     'numero_registre_essais': 'NCT02534974',
#     'numero_tranche': '5'}]},
#  'NCT02920203': {'financement_total': 190000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'AGEMOS',
#     'titre': 'Autopsie génétique et mort subite avant 40 ans',
#     'discipline_principale': 'médecine légale',
#     'nom_porteur': 'LORIN DE LA GRANDMAISON',
#     'prenom_porteur': 'Geoffroy',
#     'financement_total': 190000.0,
#     'numero_registre_essais': 'NCT02920203',
#     'numero_tranche': '2'}]},
#  'NCT02106520': {'financement_total': 704458.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ALEGORI',
#     'titre': 'Efficacité du bevacizumab en spray nasal pour le traitement des épistaxis dans la maladie de Rendu-Osler.',
#     'discipline_principale': 'médecine interne',
#     'nom_porteur': 'DUPUIS GIROD',
#     'prenom_porteur': 'Sophie',
#     'financement_total': 704458.0,
#     'numero_registre_essais': 'NCT02106520',
#     'numero_tranche': '5'}]},
#  'NCT02389231': {'financement_total': 199024.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU DE BORDEAUX',
#     'finess': 330781196,
#     'type_etablissement': 'CH',
#     'acronyme': 'ANEMIL',
#     'titre': "Essai clinique pilote de phase I/II, preuve de concept, testant l'effet de l'interleukine-2 sur les lymphocytes T CD8 régulateurs au cours des anémies hémolytiques auto-immunes à anticorps chauds résistantes aux traitements conventionnels",
#     'discipline_principale': 'médecine interne',
#     'nom_porteur': 'LAZARO',
#     'prenom_porteur': 'Estibaliz',
#     'financement_total': 199024.0,
#     'numero_registre_essais': 'NCT02389231',
#     'numero_tranche': '2'}]},
#  'NCT02839785': {'financement_total': 171462.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU BREST',
#     'finess': 290000017,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ANTALKINEPC',
#     'titre': "Antalgie et kinésithérapie chez l'enfant avec paralysie cérébrale",
#     'discipline_principale': 'médecine physique et réadaptation',
#     'nom_porteur': 'BROCHARD',
#     'prenom_porteur': 'Sylvain',
#     'financement_total': 171462.0,
#     'numero_registre_essais': 'NCT02839785',
#     'numero_tranche': '2'}]},
#  'NCT02186951': {'financement_total': 534504.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU  DE  LIMOGES',
#     'finess': 870000015,
#     'type_etablissement': 'CH',
#     'acronyme': 'ANTHARTIC',
#     'titre': 'Prévention des pneumopathies acquises sous ventilation mécanique (PAVM) précoce par antibioprothérapie et chez les patients sous hypothermie après arrêt cardiaque. Essai thérapeutique randomisé en double aveugle.',
#     'discipline_principale': 'anesthésiologie / réanimation',
#     'nom_porteur': 'FRANCOIS',
#     'prenom_porteur': 'Bruno',
#     'financement_total': 534504.0,
#     'numero_registre_essais': 'NCT02186951',
#     'numero_tranche': '5'}]},
#  'NCT02281929': {'financement_total': 499000.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Hauts-de-France',
#     'nom_etablissement': 'CHR LILLE',
#     'finess': 590780193,
#     'type_etablissement': 'CH',
#     'acronyme': 'ANTIBIOCOR HAA',
#     'titre': "Evaluation de l'efficacité de l'antibiothérapie en association à la corticothérapie dans l'hépatite alcoolique sévère. Essai contrôlé randomisé en double aveugle.",
#     'discipline_principale': 'hépatologie',
#     'nom_porteur': 'MATHURIN',
#     'prenom_porteur': 'Philippe',
#     'financement_total': 499000.0,
#     'numero_registre_essais': 'NCT02281929',
#     'numero_tranche': '3'}]},
#  'NCT02608346': {'financement_total': 548767.0,
#   'financements': [{'appel_a_projets': 'PHRCK',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'CLCC  INSTITUT CURIE',
#     'finess': 750160012,
#     'type_etablissement': 'CLCC',
#     'acronyme': 'CirCA01',
#     'titre': "Détection d'ADN tumoral circulant et suivi des femmes porteuses d'une mutation BRCA1",
#     'discipline_principale': 'oncologie médicale',
#     'nom_porteur': 'PIERGA',
#     'prenom_porteur': 'Jean-Yves',
#     'financement_total': 405091.0,
#     'numero_registre_essais': 'NCT02608346',
#     'numero_tranche': '3'},
#    {'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2015,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'CLCC  INSTITUT CURIE',
#     'finess': 750160012,
#     'type_etablissement': 'CLCC',
#     'acronyme': 'CirCA01-cell',
#     'titre': "Détection des cellules tumorales circulantes pour le diagnostic précoce des évolutions tumorales chez les femmes à risque porteuses d'une mutation BRCA1",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'BIDARD',
#     'prenom_porteur': 'François-Clément',
#     'financement_total': 143676.0,
#     'numero_registre_essais': 'NCT02608346',
#     'numero_tranche': '2'}]},
#  'NCT02392858': {'financement_total': 199987.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ANTIGRIPPE',
#     'titre': "Identification, chez les patients admis en réanimation pour une infection respiratoire grippale sévère, d'un marqueur biologique prédictif de l'évolution vers un tableau de détresse respiratoire nécessitant des soins lourds de réanimation.",
#     'discipline_principale': 'infectieux',
#     'nom_porteur': 'CASALEGNO',
#     'prenom_porteur': 'Jean-Sébastien',
#     'financement_total': 199987.0,
#     'numero_registre_essais': 'NCT02392858',
#     'numero_tranche': '4'}]},
#  'NCT02388334': {'financement_total': 264909.0,
#   'financements': [{'appel_a_projets': 'PREPS',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU RENNES',
#     'finess': 350005179,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'AQUASEP',
#     'titre': "Prendre en compte le point de vue des aidants pour évaluer la qualité des soins aux patients atteints d'une pathologie chronique : un exemple appliqué à la Sclérose en Plaques (SEP)",
#     'discipline_principale': 'organisation des soins',
#     'nom_porteur': 'VEILLARD',
#     'prenom_porteur': 'David',
#     'financement_total': 264909.0,
#     'numero_registre_essais': 'NCT02388334',
#     'numero_tranche': '4'}]},
#  'NCT02797457': {'financement_total': 4919864.0,
#   'financements': [{'appel_a_projets': 'PRME',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ARMEDIC',
#     'titre': "Evaluation médico-économique de l'allogreffe bilatérale de mains et avant-bras",
#     'discipline_principale': 'chirurgie plastique et reconstructrice',
#     'nom_porteur': 'Badet',
#     'prenom_porteur': 'Lionel',
#     'financement_total': 4919864.0,
#     'numero_registre_essais': 'NCT02797457',
#     'numero_tranche': '2'}]},
#  'NCT02906761': {'financement_total': 632121.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ASTHMIRINE',
#     'titre': "Intérêt d'un traitement prolongé par aspirine dans l'asthme non contrôlé",
#     'discipline_principale': 'pneumologie',
#     'nom_porteur': 'TAILLE',
#     'prenom_porteur': 'Camille',
#     'financement_total': 632121.0,
#     'numero_registre_essais': 'NCT02906761',
#     'numero_tranche': '2'}]},
#  'NCT02424409': {'financement_total': 542297.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ASUR R',
#     'titre': "Evaluation de l'impact sur le taux de récidive à un mois, d'un protocole formalisé strict de suivi des patients asthmatiques sortis des Urgences pour crise aiguë",
#     'discipline_principale': "médecine d'urgence",
#     'nom_porteur': 'TRUCHOT',
#     'prenom_porteur': 'Jennifer',
#     'financement_total': 542297.0,
#     'numero_registre_essais': 'NCT02424409',
#     'numero_tranche': '4'}]},
#  'NCT02768584': {'financement_total': 105017.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'GHU PARIS PSY ET NEUROSCIENCES',
#     'finess': 750062036,
#     'type_etablissement': 'EPSM',
#     'acronyme': 'ATIASP',
#     'titre': "Mesure et recherche des freins et des leviers à la construction de l'Alliance Thérapeutique avec les Infirmiers et les Aides-Soignants en Psychiatrie",
#     'discipline_principale': 'psychiatrie / addictologie',
#     'nom_porteur': 'MORVILLERS',
#     'prenom_porteur': 'Jean Manuel',
#     'financement_total': 105017.0,
#     'numero_registre_essais': 'NCT02768584',
#     'numero_tranche': '3'}]},
#  'NCT01818895': {'financement_total': 66039.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CENTRE HOSP. UNIVERSITAIRE DE POITIERS',
#     'finess': 860014208,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ARREVE',
#     'titre': 'ARREt progressif de la VEntilation mécanique ou extubation chez les patients de réanimation en fin de vie : épidémiologie et ressenti des proches et des soignants.',
#     'discipline_principale': 'anesthésiologie / réanimation',
#     'nom_porteur': 'ROBERT',
#     'prenom_porteur': 'René',
#     'financement_total': 66039.0,
#     'numero_registre_essais': 'NCT01818895',
#     'numero_tranche': '5'}]},
#  'NCT02888730': {'financement_total': 370305.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'CENTRE HOSPITALIER INTERCOM DE CRETEIL',
#     'finess': 940110018,
#     'type_etablissement': 'CH',
#     'acronyme': 'AVAS MUC',
#     'titre': "Efficacité de l'Aérosolthérapie sonique nébulisée Vecteur d'Antibiotique (tobramycine) dans le traitement de la rhino-Sinusite chronique des patients atteints de MUCoviscidose (AVASMUC): un essai randomisé contrôlé en double aveugle",
#     'discipline_principale': 'orl',
#     'nom_porteur': 'ESCABASSE',
#     'prenom_porteur': 'Virginie',
#     'financement_total': 370305.0,
#     'numero_registre_essais': 'NCT02888730',
#     'numero_tranche': '2'}]},
#  'NCT02673385': {'financement_total': 78419.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU  DE  LIMOGES',
#     'finess': 870000015,
#     'type_etablissement': 'CH',
#     'acronyme': 'BRAZMAMAN',
#     'titre': "Etude de l'impact de la passation de l'échelle de Brazelton sur la confiance de la mère à l'égard de son nouveau-né, né prématuré, à l'approche du retour à domicile.",
#     'discipline_principale': 'néonatalogie',
#     'nom_porteur': 'KACZANOWSKI',
#     'prenom_porteur': 'Ophélie',
#     'financement_total': 78419.0,
#     'numero_registre_essais': 'NCT02673385',
#     'numero_tranche': '3'}]},
#  'NCT02897895': {'financement_total': 535122.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': "Provence-Alpes-Côte d'Azur",
#     'nom_etablissement': 'APHM DIRECTION GENERALE',
#     'finess': 130786049,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CalciMo TP',
#     'titre': "Etude randomisée, contrôlée évaluant l'intérêt du suivi de l'activité CALCIneurine dans la MOdulation de l'immunosuppresion par anticalcineurine en Transplantation Pulmonaire",
#     'discipline_principale': 'pneumologie',
#     'nom_porteur': 'REYNAUD GAUBERT',
#     'prenom_porteur': 'Martine',
#     'financement_total': 535122.0,
#     'numero_registre_essais': 'NCT02897895',
#     'numero_tranche': '1'}]},
#  'NCT02271295': {'financement_total': 703408.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CHILBENOX',
#     'titre': "Impact de l'anticoagulation à dose préventive par héparine de bas poids moléculaire sur la morbimortalité chez les patients cirrhotiques Child B : Essai randomisé multicentrique",
#     'discipline_principale': 'hépatologie',
#     'nom_porteur': 'POUJOL ROBERT',
#     'prenom_porteur': 'Armelle',
#     'financement_total': 703408.0,
#     'numero_registre_essais': 'NCT02271295',
#     'numero_tranche': '2'}]},
#  'NCT02154828': {'financement_total': 323906.0,
#   'financements': [{'appel_a_projets': 'PREPS',
#     'annee_de_selection': 2013,
#     'region': 'Pays de la Loire',
#     'nom_etablissement': 'CHU DE NANTES',
#     'finess': 440000289,
#     'type_etablissement': 'CH',
#     'acronyme': 'AUTISME',
#     'titre': 'Evaluation clinique des pratiques intégratives en unités de soins infanto-juvéniles pour des enfants présentant un autisme typique ou atypique.',
#     'discipline_principale': 'psychiatrie / addictologie',
#     'nom_porteur': 'GARRET',
#     'prenom_porteur': 'Nicole',
#     'financement_total': 323906.0,
#     'numero_registre_essais': 'NCT02154828',
#     'numero_tranche': '4'}]},
#  'NCT02096822': {'financement_total': 31837.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BABYDOUL',
#     'titre': "Evaluation de l'efficacité du regroupement f\x9ctal en association avec la succion d'une tétine avec eau stérile sur la douleur lors d'un prélèvement capillaire chez le grand prématuré.",
#     'discipline_principale': 'néonatalogie',
#     'nom_porteur': 'PERROTEAU',
#     'prenom_porteur': 'Anne',
#     'financement_total': 31837.0,
#     'numero_registre_essais': 'NCT02096822',
#     'numero_tranche': '4'}]},
#  'NCT01315639': {'financement_total': 273978.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BALTAZAR PlaTau',
#     'titre': "Protéine tau plasmatique et biomarqueurs de la dégradation de l'APP (Amyloid precursor protein) pour le diagnostic et le pronostic de la maladie d'Alzheimer. Etude ancillaire à l'étude BALTAZAR (Biomarker of AmyLoïd pepTide and AlZheimer's diseAse Risk).",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'HANON',
#     'prenom_porteur': 'Olivier',
#     'financement_total': 273978.0,
#     'numero_registre_essais': 'NCT01315639',
#     'numero_tranche': '3'}]},
#  'NCT02410304': {'financement_total': 198100.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU BREST',
#     'finess': 290000017,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BCD',
#     'titre': "Etude pragmatique comparant les méthodes d'évaluation clinique (C) et/ou échographique (mode B ou D) de la polyarthrite rhumatoïde pour guider l'adaptation thérapeutique",
#     'discipline_principale': 'rhumatologie',
#     'nom_porteur': 'JOUSSE-JOULIN',
#     'prenom_porteur': 'Sandrine',
#     'financement_total': 198100.0,
#     'numero_registre_essais': 'NCT02410304',
#     'numero_tranche': '3'}]},
#  'NCT02330952': {'financement_total': 525500.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BECOMEG',
#     'titre': "Efficacité et tolérance d'une corticothérapie orale pour la prise en charge des exacerbations aiguës de BPCO en médecine générale",
#     'discipline_principale': 'médecine générale',
#     'nom_porteur': 'GHASAROSSIAN',
#     'prenom_porteur': 'Christian',
#     'financement_total': 525500.0,
#     'numero_registre_essais': 'NCT02330952',
#     'numero_tranche': '4'}]},
#  'NCT02356939': {'financement_total': 176000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BILIDRAINT',
#     'titre': "Essai comparatif randomisé évaluant l'efficacité de la mise en place d'un drain biliaire interne au cours de la reconstruction biliaire dans la prévention des complications biliaires après transplantation hépatique",
#     'discipline_principale': 'hge',
#     'nom_porteur': 'SCATTON',
#     'prenom_porteur': 'Olivier',
#     'financement_total': 176000.0,
#     'numero_registre_essais': 'NCT02356939',
#     'numero_tranche': '4'}]},
#  'NCT01876459': {'financement_total': 200000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Grand Est',
#     'nom_etablissement': 'HOPITAUX UNIVERSITAIRES DE STRASBOURG',
#     'finess': 670780055,
#     'type_etablissement': 'CH',
#     'acronyme': 'Biomarqueurs-Lewy',
#     'titre': 'Identification de nouveaux biomarqueurs de la Maladie à Corps de Lewy',
#     'discipline_principale': 'neurologie , maladie dégénérative ,',
#     'nom_porteur': 'BLANC',
#     'prenom_porteur': 'Frédéric',
#     'financement_total': 200000.0,
#     'numero_registre_essais': 'NCT01876459',
#     'numero_tranche': '3'}]},
#  'NCT02325310': {'financement_total': 277029.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'BREMEAVAC',
#     'titre': "Recherche de l'excrétion du virus vaccinal de la rougeole dans le lait de femmes vaccinées en postpartum par un vaccin trivalent Rougeole-Rubéole-Oreillons(RRO)",
#     'discipline_principale': 'infectiologie / biologie des agents infectieux / hygiène',
#     'nom_porteur': 'LAUNAY',
#     'prenom_porteur': 'Odile',
#     'financement_total': 277029.0,
#     'numero_registre_essais': 'NCT02325310',
#     'numero_tranche': '4'}]},
#  'NCT02617017': {'financement_total': 386471.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'Buspark',
#     'titre': 'Effet de la buspirone sur les dyskinésies iatrogènes de la maladie de Parkinson avancée. Essai multicentrique de phase II, international, randomisé double insu, contrôlé, contre placebo, en deux groupes parallèles.',
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'FENELON',
#     'prenom_porteur': 'Gilles',
#     'financement_total': 386471.0,
#     'numero_registre_essais': 'NCT02617017',
#     'numero_tranche': '3'}]},
#  'NCT02332447': {'financement_total': 422059.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ENALEPSIE',
#     'titre': "Efficacité de la Naloxone sur les troubles respiratoires centraux compliquant les crises d'épilepsie",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'RHEIMS',
#     'prenom_porteur': 'Sylvain',
#     'financement_total': 422059.0,
#     'numero_registre_essais': 'NCT02332447',
#     'numero_tranche': '4'}]},
#  'NCT02327026': {'financement_total': 562734.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CAAM',
#     'titre': "Prise en charge initiale des voies aériennes au cours de l'arrêt cardiaque extra-hospitalier: intubation endotrachéale versus ventilation au masque",
#     'discipline_principale': "médecine d'urgence",
#     'nom_porteur': 'ADNET',
#     'prenom_porteur': 'Frédéric',
#     'financement_total': 562734.0,
#     'numero_registre_essais': 'NCT02327026',
#     'numero_tranche': '5'}]},
#  'NCT03137641': {'financement_total': 199203.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU DE BORDEAUX',
#     'finess': 330781196,
#     'type_etablissement': 'CH',
#     'acronyme': 'CACIES',
#     'titre': 'Evaluation de la contamination interne par les médicaments anticancéreux du personnel infirmier en Etablissement de soins',
#     'discipline_principale': 'médecine du travail',
#     'nom_porteur': 'VERDUN ESQUER',
#     'prenom_porteur': 'Catherine',
#     'financement_total': 199203.0,
#     'numero_registre_essais': 'NCT03137641',
#     'numero_tranche': '5'}]},
#  'NCT02265445': {'financement_total': 612973.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'Carbepargne',
#     'titre': 'Désescalade des carbapénèmes: étude multicentrique contrôlée randomisée comparant maintien des carbapénèmes et relais par une autre béta-lactamine dans le traitement des infections à Entérobactéries productrices de béta-lactamases à spectre élargi.',
#     'discipline_principale': 'infectiologie / biologie des agents infectieux / hygiène',
#     'nom_porteur': 'LESPRIT',
#     'prenom_porteur': 'Philippe',
#     'financement_total': 612973.0,
#     'numero_registre_essais': 'NCT02265445',
#     'numero_tranche': '2'}]},
#  'NCT02304939': {'financement_total': 87988.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Pays de la Loire',
#     'nom_etablissement': 'CHR ANGERS',
#     'finess': 490000031,
#     'type_etablissement': 'CH',
#     'acronyme': 'CHIC',
#     'titre': 'Impact de la méthode de relais de noradrénaline sur la stabilité de la pression artérielle chez le patients en état de choc en réanimation.',
#     'discipline_principale': 'projet non concerné par les plans de santé publique listés ci-dessus',
#     'nom_porteur': 'LE ROY',
#     'prenom_porteur': 'Cyril',
#     'financement_total': 87988.0,
#     'numero_registre_essais': 'NCT02304939',
#     'numero_tranche': '4'}]},
#  'NCT02204618': {'financement_total': 1153363.0,
#   'financements': [{'appel_a_projets': 'PRME',
#     'annee_de_selection': 2013,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU TOULOUSE',
#     'finess': 310781406,
#     'type_etablissement': 'CH',
#     'acronyme': 'CISSD',
#     'titre': "Implantation cochléaire dans les surdités profondes unilatérales de l'adulte : évaluation coût-utilité",
#     'discipline_principale': 'orl',
#     'nom_porteur': 'Marx',
#     'prenom_porteur': 'Mathieu',
#     'financement_total': 1153363.0,
#     'numero_registre_essais': 'NCT02204618',
#     'numero_tranche': '5'}]},
#  'NCT03257319': {'financement_total': 523520.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Normandie',
#     'nom_etablissement': 'CHU ROUEN',
#     'finess': 760780239,
#     'type_etablissement': 'CH',
#     'acronyme': 'CLIN AEROMORPH',
#     'titre': 'Evaluation de la titration morphinique par nébulisation dans les douleurs aigues sévères aux urgences',
#     'discipline_principale': "médecine d'urgence",
#     'nom_porteur': 'LVOVSCHI',
#     'prenom_porteur': 'Virginie',
#     'financement_total': 523520.0,
#     'numero_registre_essais': 'NCT03257319',
#     'numero_tranche': '2'}]},
#  'NCT02320357': {'financement_total': 124051.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU DE BORDEAUX',
#     'finess': 330781196,
#     'type_etablissement': 'CH',
#     'acronyme': 'CLOPUS',
#     'titre': "Essai pilote de phase I/II testant l'effet du clopidogrel sur les taux plasmatiques de CD40 ligand soluble chez des patients affectés de lupus érythémateux systémique.",
#     'discipline_principale': 'médecine interne,',
#     'nom_porteur': 'DUFFAU',
#     'prenom_porteur': 'Pierre',
#     'financement_total': 124051.0,
#     'numero_registre_essais': 'NCT02320357',
#     'numero_tranche': '5'}]},
#  'NCT02474706': {'financement_total': 590355.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Grand Est',
#     'nom_etablissement': 'CHRU DE NANCY',
#     'finess': 540023264,
#     'type_etablissement': 'CH',
#     'acronyme': 'COLIFOX',
#     'titre': 'Essai de non-infériorité de la céfoxitine versus ertapénème dans le traitement des infections urinaires à Escherichia coli producteurs de BLSE.',
#     'discipline_principale': 'infectiologie / biologie des agents infectieux / hygiène',
#     'nom_porteur': 'MAY',
#     'prenom_porteur': 'Thierry',
#     'financement_total': 590355.0,
#     'numero_registre_essais': 'NCT02474706',
#     'numero_tranche': '2'}]},
#  'NCT02906722': {'financement_total': 411947.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'COLIVAP',
#     'titre': "Comparaison de l'efficacité de la Colimycine par nébulisation et par voie intraveineuse au cours des pneumonies à bacilles gram négatif multi-résistantes acquises sous ventilation mécanique : Etude prospective, multicentrique, randomisée en double aveugle",
#     'discipline_principale': 'anesthésiologie / réanimation',
#     'nom_porteur': 'LU',
#     'prenom_porteur': 'Qin',
#     'financement_total': 411947.0,
#     'numero_registre_essais': 'NCT02906722',
#     'numero_tranche': '2'}]},
#  'NCT03011411': {'financement_total': 95000.0,
#   'financements': [{'appel_a_projets': 'PREPS',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'COMERE',
#     'titre': 'COmparaison des MEthodes de REcueil des consommations de soins des patients inclus dans les projets de recherche clinique intégrant une évaluation médico-économique',
#     'discipline_principale': 'economie de la santé',
#     'nom_porteur': 'CHEVREUL',
#     'prenom_porteur': 'Karine',
#     'financement_total': 95000.0,
#     'numero_registre_essais': 'NCT03011411',
#     'numero_tranche': '5'}]},
#  'NCT02381665': {'financement_total': 219474.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': "Provence-Alpes-Côte d'Azur",
#     'nom_etablissement': 'APHM DIRECTION GENERALE',
#     'finess': 130786049,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CON COUR',
#     'titre': "Evaluation de l'efficacité du courant interférentiel dans le traitement de la constipation chronique de l'adulte : essai multicentrique",
#     'discipline_principale': 'gastro-entérologie',
#     'nom_porteur': 'VITTON',
#     'prenom_porteur': 'Véronique',
#     'financement_total': 219474.0,
#     'numero_registre_essais': 'NCT02381665',
#     'numero_tranche': '2'}]},
#  'NCT02906657': {'financement_total': 551162.0,
#   'financements': [{'appel_a_projets': 'PREPS',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CONCIPAGE',
#     'titre': "Développement de la conciliation médicamenteuse à l'aide du dossier pharmaceutique. Etude multicentrique nationale chez le sujet âgé hospitalisé en service de gériatrie, médecine interne et chirurgie orthopédique.",
#     'discipline_principale': 'médecine interne',
#     'nom_porteur': 'FERNANDEZ',
#     'prenom_porteur': 'Christine',
#     'financement_total': 551162.0,
#     'numero_registre_essais': 'NCT02906657',
#     'numero_tranche': '4'}]},
#  'NCT02874469': {'financement_total': 49661.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Hauts-de-France',
#     'nom_etablissement': 'CHR LILLE',
#     'finess': 590780193,
#     'type_etablissement': 'CH',
#     'acronyme': 'COREABOR',
#     'titre': "« Comment combler le « trou de la réa » par l'instauration d'un JOURNAL de BORD après une MORT SUBITE RESSUSCITEE : Impact sur le syndrome de stress post-traumatique chez le patient et ses proches",
#     'discipline_principale': 'anesthésiologie / réanimation',
#     'nom_porteur': 'DEHAUT',
#     'prenom_porteur': 'Hélène',
#     'financement_total': 49661.0,
#     'numero_registre_essais': 'NCT02874469',
#     'numero_tranche': '3'}]},
#  'NCT02434679': {'financement_total': 199948.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU  DE  LIMOGES',
#     'finess': 870000015,
#     'type_etablissement': 'CH',
#     'acronyme': 'DAIR3N',
#     'titre': "Dynamique d'acquisition d'intégrons de résistance aux antibiotiques chez les nouveau-nés de néonatologie",
#     'discipline_principale': 'gynéco-obstétrique',
#     'nom_porteur': 'GARNIER',
#     'prenom_porteur': 'Fabien',
#     'financement_total': 199948.0,
#     'numero_registre_essais': 'NCT02434679',
#     'numero_tranche': '4'}]},
#  'NCT02606162': {'financement_total': 597742.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'CROSS',
#     'titre': 'Conséquences des fractures sévères ostéoporotiques hospitalisées en France : cohorte française multicentrique CROSS',
#     'discipline_principale': 'rhumatologie',
#     'nom_porteur': 'BRIOT',
#     'prenom_porteur': 'Karine',
#     'financement_total': 597742.0,
#     'numero_registre_essais': 'NCT02606162',
#     'numero_tranche': '3'}]},
#  'NCT02244450': {'financement_total': 2124851.0,
#   'financements': [{'appel_a_projets': 'PRME',
#     'annee_de_selection': 2013,
#     'region': 'Pays de la Loire',
#     'nom_etablissement': 'CHU DE NANTES',
#     'finess': 440000289,
#     'type_etablissement': 'CH',
#     'acronyme': 'DEPISTREC',
#     'titre': "Evaluation de l'utilité clinique et médico-économique du dépistage néonatal généralisé des Déficits Immunitaires Combinés Sévères (DICS) par quantification des TRECs sur cartes de Guthrie",
#     'discipline_principale': 'biologie',
#     'nom_porteur': 'Audrain',
#     'prenom_porteur': 'Marie',
#     'financement_total': 2124851.0,
#     'numero_registre_essais': 'NCT02244450',
#     'numero_tranche': '5'}]},
#  'NCT02268903': {'financement_total': 647699.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'DiPER',
#     'titre': "Diurétique versus placebo dans l'embolie pulmonaire avec dilatation du ventricule droit",
#     'discipline_principale': 'cardiologie',
#     'nom_porteur': 'DUBOIS RANDE',
#     'prenom_porteur': 'Jean Luc',
#     'financement_total': 647699.0,
#     'numero_registre_essais': 'NCT02268903',
#     'numero_tranche': '5'}]},
#  'NCT02205541': {'financement_total': 1478262.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU TOULOUSE',
#     'finess': 310781406,
#     'type_etablissement': 'CH',
#     'acronyme': 'ECULISHU',
#     'titre': "Traitement précoce par l'anticorps monoclonal anti C5 eculizumab de patients pédiatriques atteints d'un syndrome hémolytique et urémique à Escherichia Coli sécréteurs de Shiga-toxine: essai clinique de phase III prospectif contrôlé randomisé contre placebo",
#     'discipline_principale': 'néphrologie',
#     'nom_porteur': 'GARNIER',
#     'prenom_porteur': 'Arnaud',
#     'financement_total': 1478262.0,
#     'numero_registre_essais': 'NCT02205541',
#     'numero_tranche': '4'}]},
#  'NCT02307942': {'financement_total': 725730.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU TOULOUSE',
#     'finess': 310781406,
#     'type_etablissement': 'CH',
#     'acronyme': 'ELDSURG',
#     'titre': "Evaluation du bénéfice d'une perte de poids intense (obtenue par technique chirurgicale) sur les capacités fonctionnelles de personnes âgées obèses de plus de 60 ans bénéficiant d'un entraînement physique. Comparaison à une perte de poids modeste obtenue par restriction calorique.",
#     'discipline_principale': 'nutrition et obésité',
#     'nom_porteur': 'RITZ',
#     'prenom_porteur': 'Patrick',
#     'financement_total': 725730.0,
#     'numero_registre_essais': 'NCT02307942',
#     'numero_tranche': '3'}]},
#  'NCT02949635': {'financement_total': 200000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Hauts-de-France',
#     'nom_etablissement': 'CHR LILLE',
#     'finess': 590780193,
#     'type_etablissement': 'CH',
#     'acronyme': 'DAMAGe',
#     'titre': 'Etude du Devenir Après une Hospitalisation en Médecine Aiguë Gériatrique',
#     'discipline_principale': 'medecine aigue , geriatrie , mortalite , re-hospitalisation , institutionnalisation',
#     'nom_porteur': 'BEUSCART',
#     'prenom_porteur': 'Jean-Baptiste',
#     'financement_total': 200000.0,
#     'numero_registre_essais': 'NCT02949635',
#     'numero_tranche': '5'}]},
#  'NCT02869945': {'financement_total': 197000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'DATaCOMT',
#     'titre': 'Dénervation dopaminergique et polymorphisme de la COMT chez les patients parkinsoniens de novo',
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'GRABLI',
#     'prenom_porteur': 'David',
#     'financement_total': 197000.0,
#     'numero_registre_essais': 'NCT02869945',
#     'numero_tranche': '3'}]},
#  'NCT02286388': {'financement_total': 776984.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'DECAT',
#     'titre': "Etude clinique randomisée multicentrique comparant l'éviction partielle en un temps à l'éviction complète lors du traitement des lésions carieuses profondes des dents permanentes.",
#     'discipline_principale': 'odontologie',
#     'nom_porteur': 'GROSGOGEAT',
#     'prenom_porteur': 'Brigitte',
#     'financement_total': 776984.0,
#     'numero_registre_essais': 'NCT02286388',
#     'numero_tranche': '3'}]},
#  'NCT04026854': {'financement_total': 84387.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Centre-Val de Loire',
#     'nom_etablissement': 'CHU DE TOURS',
#     'finess': 370000481,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'DETERQVT',
#     'titre': 'Déterminants individuels, organisationnels et managériaux, de la qualité de vie au travail des infirmiers en psychiatrie et retentissement sur la qualité des soins',
#     'discipline_principale': 'psychiatrie / addictologie',
#     'nom_porteur': 'CHEYROUX',
#     'prenom_porteur': 'Pierre',
#     'financement_total': 84387.0,
#     'numero_registre_essais': 'NCT04026854',
#     'numero_tranche': '5'}]},
#  'NCT02167802': {'financement_total': 247835.0,
#   'financements': [{'appel_a_projets': 'PREPS-IQ',
#     'annee_de_selection': 2013,
#     'region': 'Pays de la Loire',
#     'nom_etablissement': 'CHU DE NANTES',
#     'finess': 440000289,
#     'type_etablissement': 'CH',
#     'acronyme': 'DIABACT IV',
#     'titre': "Validation d'indicateurs de prise en charge sub-optimale dans les infections bactériennes communautaires sévères de l'enfant",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'GRAS-LE GUEN',
#     'prenom_porteur': 'Christèle',
#     'financement_total': 247835.0,
#     'numero_registre_essais': 'NCT02167802',
#     'numero_tranche': '4'}]},
#  'NCT01743274': {'financement_total': 340538.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Bourgogne-Franche-Comté',
#     'nom_etablissement': 'CHU BESANCON',
#     'finess': 250000015,
#     'type_etablissement': 'CH',
#     'acronyme': 'DOCTORS',
#     'titre': "La Tomographie par Cohérence Optique améliore-t-elle le résultat de la mise en place d'une prothèse endocoronaire?",
#     'discipline_principale': 'cardiologie',
#     'nom_porteur': 'MENEVEAU',
#     'prenom_porteur': 'Nicolas',
#     'financement_total': 340538.0,
#     'numero_registre_essais': 'NCT01743274',
#     'numero_tranche': '5'}]},
#  'NCT02486965': {'financement_total': 160646.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU BREST',
#     'finess': 290000017,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'DOUFISPORT',
#     'titre': "Impact d'un programme d'entraînement spécifique sur la neuromodulation des douleurs chez les sujets fibromyalgiques",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'BODERE',
#     'prenom_porteur': 'Céline',
#     'financement_total': 160646.0,
#     'numero_registre_essais': 'NCT02486965',
#     'numero_tranche': '3'}]},
#  'NCT02261870': {'financement_total': 718748.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Grand Est',
#     'nom_etablissement': 'CHRU DE NANCY',
#     'finess': 540023264,
#     'type_etablissement': 'CH',
#     'acronyme': 'DRAGET',
#     'titre': 'Detection du Rejet Aigu de Greffe cardiaque par Estimation du T2 en IRM',
#     'discipline_principale': 'cardiologie',
#     'nom_porteur': 'BONNEMAINS',
#     'prenom_porteur': 'Laurent',
#     'financement_total': 718748.0,
#     'numero_registre_essais': 'NCT02261870',
#     'numero_tranche': '4'}]},
#  'NCT02216565': {'financement_total': 197000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'HOPITAL FONDATION A DE ROTHSCHILD',
#     'finess': 750000549,
#     'type_etablissement': 'EBNL',
#     'acronyme': 'EASYTRIAL',
#     'titre': 'Embolectomie des occlusions sylviennes aigues chez les patients réfractaires ou non éligibles à l\'alteplase. Un essai contrôlé-randomisé multicentrique " EASYTRIAL for Embolectomy of Acute SYlvian Thrombosis in Refractory or Ineligible patients to ALtepla',
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'LABEYRIE',
#     'prenom_porteur': 'Marc-Antoine',
#     'financement_total': 197000.0,
#     'numero_registre_essais': 'NCT02216565',
#     'numero_tranche': '2'}]},
#  'NCT02313350': {'financement_total': 545489.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'EDIS',
#     'titre': 'Efficacité du Discogel Intradiscal dans la Sciatique résistant au traitement médical : étude de non-infériorité en comparaison avec la chirurgie',
#     'discipline_principale': 'anatomie et cytologie pathologiques',
#     'nom_porteur': 'BEAUDREUIL',
#     'prenom_porteur': 'Johann',
#     'financement_total': 545489.0,
#     'numero_registre_essais': 'NCT02313350',
#     'numero_tranche': '2'}]},
#  'NCT02123277': {'financement_total': 74843.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU MONTPELLIER',
#     'finess': 340780477,
#     'type_etablissement': 'CH',
#     'acronyme': 'EDITO',
#     'titre': "Evaluation a long terme de la dilatation tubaire dans les dysfonctions obstructives chroniques de la trompe d'eustache",
#     'discipline_principale': 'orl cmf',
#     'nom_porteur': 'VENAIL',
#     'prenom_porteur': 'Frédéric',
#     'financement_total': 74843.0,
#     'numero_registre_essais': 'NCT02123277',
#     'numero_tranche': '3'}]},
#  'NCT02100046': {'financement_total': 187000.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'CHU DE CLERMONT-FERRAND',
#     'finess': 630780989,
#     'type_etablissement': 'CH',
#     'acronyme': 'EDONOT',
#     'titre': "Evaluation de l'efficacité de l'éthosuximide dans le traitement de douleurs neuropathiques d'origine traumatique",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'ESCHALIER',
#     'prenom_porteur': 'Alain',
#     'financement_total': 187000.0,
#     'numero_registre_essais': 'NCT02100046',
#     'numero_tranche': '3'}]},
#  'NCT02089139': {'financement_total': 82139.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU  DE  LIMOGES',
#     'finess': 870000015,
#     'type_etablissement': 'CH',
#     'acronyme': 'EGID',
#     'titre': "Efficacité de l'Ethanol Gélifié en injection Intradiscale dans le traitement de la lombalgie Discogénique",
#     'discipline_principale': 'neurochirurgie',
#     'nom_porteur': 'CAIRE',
#     'prenom_porteur': 'François',
#     'financement_total': 82139.0,
#     'numero_registre_essais': 'NCT02089139',
#     'numero_tranche': '2'}]},
#  'NCT02625116': {'financement_total': 688209.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU MONTPELLIER',
#     'finess': 340780477,
#     'type_etablissement': 'CH',
#     'acronyme': 'ELENA E1',
#     'titre': "Etude des déterminants de l'évolution dans une cohorte d'enfants et adolescents avec Troubles du Spectre Autistique (TSA) \x96 Etape 1",
#     'discipline_principale': 'psychiatrie / addictologie',
#     'nom_porteur': 'BAGHDADLI',
#     'prenom_porteur': 'Amaria',
#     'financement_total': 688209.0,
#     'numero_registre_essais': 'NCT02625116',
#     'numero_tranche': '3'}]},
#  'NCT02251262': {'financement_total': 368211.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU DE BORDEAUX',
#     'finess': 330781196,
#     'type_etablissement': 'CH',
#     'acronyme': 'ENDOTEP',
#     'titre': "Evaluation de l'exactitude diagnostique du 18FDG-TEP-TDM dans le diagnostic d'infection sur sonde de stimulation ou de défibrillateur cardiaques : étude prospective multicentrique",
#     'discipline_principale': 'cardiologie',
#     'nom_porteur': 'BORDACHAR',
#     'prenom_porteur': 'Pierre',
#     'financement_total': 368211.0,
#     'numero_registre_essais': 'NCT02251262',
#     'numero_tranche': '4'}]},
#  'NCT02042235': {'financement_total': 295443.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2013,
#     'region': 'Hauts-de-France',
#     'nom_etablissement': "GCS GHICL DES HOPITAUX DE L'ICL",
#     'finess': 590051801,
#     'type_etablissement': 'GCS',
#     'acronyme': 'EPILANG',
#     'titre': 'Efficacité de la guidance parentale orthophonique pour les grands prématurés avec un retard de langage.',
#     'discipline_principale': 'néonatalogie',
#     'nom_porteur': 'CHARKALUK',
#     'prenom_porteur': 'Marie Laure',
#     'financement_total': 295443.0,
#     'numero_registre_essais': 'NCT02042235',
#     'numero_tranche': '3'}]},
#  'NCT02304029': {'financement_total': 186611.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2013,
#     'region': "Provence-Alpes-Côte d'Azur",
#     'nom_etablissement': 'APHM DIRECTION GENERALE',
#     'finess': 130786049,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'EPISODIUM',
#     'titre': "Intérêt de l'IRM du sodium pour la localisation non invasive des régions épileptogènes dans les épilepsies partielles pharmaco-résistantes",
#     'discipline_principale': 'neurologie et imagerie médicale',
#     'nom_porteur': 'GUYE',
#     'prenom_porteur': 'Maxime',
#     'financement_total': 186611.0,
#     'numero_registre_essais': 'NCT02304029',
#     'numero_tranche': '3'}]},
#  'NCT02350556': {'financement_total': 93011.0,
#   'financements': [{'appel_a_projets': 'PHRIP',
#     'annee_de_selection': 2013,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU RENNES',
#     'finess': 350005179,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'EQHEM',
#     'titre': "Corrélations entre le déplacement du centre de masse des hémiplégiques lors d'une épreuve dynamique et un score fonctionnel d'équilibre : le Timed up and Go test.",
#     'discipline_principale': 'médecine physique et réadaptation',
#     'nom_porteur': 'BETHUEL',
#     'prenom_porteur': 'Arnaud',
#     'financement_total': 93011.0,
#     'numero_registre_essais': 'NCT02350556',
#     'numero_tranche': '4'}]},
#  'NCT02157987': {'financement_total': 199208.0,
# ...
#     'discipline_principale': 'néphrologie',
#     'nom_porteur': 'Seitz-Polski',
#     'prenom_porteur': 'Barbara',
#     'financement_total': 792497.0,
#     'numero_registre_essais': 'NCT03804359',
#     'numero_tranche': '3'}]},
#  'NCT03562000': {'financement_total': 218904.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PREXFAIL',
#     'titre': 'PReventing EXtubation FAILure by  Cough Assistance and NIV in a population selected on Cough Peak Flow',
#     'discipline_principale': 'hors cancer',
#     'nom_porteur': 'GOBERT',
#     'prenom_porteur': 'Florent',
#     'financement_total': 218904.0,
#     'numero_registre_essais': 'NCT03562000',
#     'numero_tranche': '2'}]},
#  'NCT03841942': {'financement_total': 693399.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU MONTPELLIER',
#     'finess': 340780477,
#     'type_etablissement': 'CH',
#     'acronyme': 'SPACIFIX',
#     'titre': "Comparaison de l'espacement des perfusions d'infliximab guidé par le dosage des taux résiduels d'infliximab à un espacement guidé par la clinique chez les patients atteints de maladies inflammatoires chroniques de l'intestin en rémission profonde Etude prospective, multicentrique, randomisée, controlée en ouvert",
#     'discipline_principale': 'gastro-entérologie',
#     'nom_porteur': 'Pineton De Chambrun',
#     'prenom_porteur': 'Guillaume',
#     'financement_total': 693399.0,
#     'numero_registre_essais': 'NCT03841942',
#     'numero_tranche': '2'}]},
#  'NCT03819309': {'financement_total': 324761.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PACTOL',
#     'titre': 'Efficacité de la ponction transvaginale pour le traitement des abcès tubo-ovariens par rapport à la laparoscopie : Etude prospective comparative randomisée contrôlée de non infériorité',
#     'discipline_principale': 'autre',
#     'nom_porteur': 'KOSKAS',
#     'prenom_porteur': 'Martin',
#     'financement_total': 324761.0,
#     'numero_registre_essais': 'NCT03819309',
#     'numero_tranche': '2'}]},
#  'NCT02811705': {'financement_total': 260915.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'CENTRE HOSPITALIER  DE VERSAILLES',
#     'finess': 780110078,
#     'type_etablissement': 'CH',
#     'acronyme': 'PFAPACOL',
#     'titre': "Etude de l'efficacité de la colchicine dans le syndrome PFAPA : étude prospective randomisée en double aveugle",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'HENTGEN',
#     'prenom_porteur': 'Véronique',
#     'financement_total': 260915.0,
#     'numero_registre_essais': 'NCT02811705',
#     'numero_tranche': '1'}]},
#  'NCT03992222': {'financement_total': 397007.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PREPAD',
#     'titre': "Prévention de la perte d'autonomie de la personne âgée à domicile par un programme d'exercices physiques ciblé sur des appareils de renforcement musculaire adaptés.",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'FRANÇOIS FASILLE',
#     'prenom_porteur': 'Véronique',
#     'financement_total': 397007.0,
#     'numero_registre_essais': 'NCT03992222',
#     'numero_tranche': '2'}]},
#  'NCT04220931': {'financement_total': 668535.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PREPARE',
#     'titre': 'Injection intrapapillaire de toxine botulique en prévention de la fistule pancréatique post-chirurgicale',
#     'discipline_principale': 'gastro-entérologie',
#     'nom_porteur': 'Palazzo',
#     'prenom_porteur': 'Maxime',
#     'financement_total': 668535.0,
#     'numero_registre_essais': 'NCT04220931',
#     'numero_tranche': '2'}]},
#  'NCT03730636': {'financement_total': 1301224.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PROABIS',
#     'titre': "Procalcitonine et durée de l'AntiBiothérapie dans l'Infection Secondaire du nouveau-né",
#     'discipline_principale': 'néonatalogie',
#     'nom_porteur': 'Mitanchez',
#     'prenom_porteur': 'Delphine',
#     'financement_total': 1301224.0,
#     'numero_registre_essais': 'NCT03730636',
#     'numero_tranche': '2'}]},
#  'NCT02889003': {'financement_total': 131233.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'CENTRE HOSPITALIER  DE VERSAILLES',
#     'finess': 780110078,
#     'type_etablissement': 'CH',
#     'acronyme': 'PIO2STOP',
#     'titre': "Étude de la combinaison de la pioglitazone et d'un traitement par Inhibiteurs de Tyrosine Kinase (ITKs) chez des patients atteints de Leucémie Myéloïde Chronique, en échec d'une première tentative d'arrêt des ITKs, afin de préparer une nouvelle tentative d'arrêt",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'DE GUNZBURG',
#     'prenom_porteur': 'Noémie',
#     'financement_total': 131233.0,
#     'numero_registre_essais': 'NCT02889003',
#     'numero_tranche': '2'}]},
#  'NCT03894657': {'financement_total': 415592.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PREDICTCF',
#     'titre': "Validation de l'exploration fonctionnelle épithéliale pour prédire la réponse clinique de Orkambi® un modulateur de la protéine CFTR. Vers une thérapie personnalisée de la mucoviscidose",
#     'discipline_principale': 'pneumologie',
#     'nom_porteur': 'Sermet-Gaudelus',
#     'prenom_porteur': 'Isabelle',
#     'financement_total': 415592.0,
#     'numero_registre_essais': 'NCT03894657',
#     'numero_tranche': '3'}]},
#  'NCT03659708': {'financement_total': 750570.0,
#   'financements': [{'appel_a_projets': 'PRME',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PRESCOT',
#     'titre': 'Prospective multicentre randomized clinical trial on the management of pregnancies with high risk of venous thrombosis',
#     'discipline_principale': 'médecine vasculaire',
#     'nom_porteur': 'Dargaud',
#     'prenom_porteur': 'Yesim',
#     'financement_total': 750570.0,
#     'numero_registre_essais': 'NCT03659708',
#     'numero_tranche': '2'}]},
#  'NCT03596476': {'financement_total': 476081.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PRIMER',
#     'titre': 'Performance diagnostique la manométrie-impédance \x9csophagienne post prandiale pour le diagnostic de reflux gastro-\x9csophagien chez les patients présentant des symptômes de reflux résistants au traitement par inhibiteurs de la pompe à protons',
#     'discipline_principale': 'explorations fonctionnelles',
#     'nom_porteur': 'Roman',
#     'prenom_porteur': 'Sabine',
#     'financement_total': 476081.0,
#     'numero_registre_essais': 'NCT03596476',
#     'numero_tranche': '2'}]},
#  'NCT03837444': {'financement_total': 399955.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'PROMICE',
#     'titre': 'Performances des microvésicules et des monocytes pour prédire la mortalité des malades atteints de cirrhose',
#     'discipline_principale': 'autre',
#     'nom_porteur': 'WEISS',
#     'prenom_porteur': 'Emmanuel',
#     'financement_total': 399955.0,
#     'numero_registre_essais': 'NCT03837444',
#     'numero_tranche': '3'}]},
#  'NCT03942848': {'financement_total': 324671.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'SPIDOL',
#     'titre': "Etude de l'efficacité antalgique du Ziconotide intrathecal pour le traitement des douleurs neuropathiques réfractaires et secondaires à une lésion spinale",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'Mertens',
#     'prenom_porteur': 'Patrick',
#     'financement_total': 324671.0,
#     'numero_registre_essais': 'NCT03942848',
#     'numero_tranche': '2'}]},
#  'NCT04016246': {'financement_total': 591550.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'CHU GRENOBLE ALPES',
#     'finess': 380780080,
#     'type_etablissement': 'CH',
#     'acronyme': 'PROLISA',
#     'titre': "Evaluation d'une sédation par Propofol au cours d'une administration intra trachéale de surfactant par méthode LISA (Less Invasive Surfactant Administration)",
#     'discipline_principale': 'néonatalogie',
#     'nom_porteur': 'Debillon',
#     'prenom_porteur': 'Thierry',
#     'financement_total': 591550.0,
#     'numero_registre_essais': 'NCT04016246',
#     'numero_tranche': '2'}]},
#  'NCT03766087': {'financement_total': 566218.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': "Provence-Alpes-Côte d'Azur",
#     'nom_etablissement': 'CTRE HOSPITALIER UNIVERSITAIRE DE NICE',
#     'finess': 60785011,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'randecped',
#     'titre': "Intérêt de la craniectomie décompressive dans le traumatisme crânien sévère de l'enfant avec hypertension intracrânienne réfractaire.",
#     'discipline_principale': 'neurologie',
#     'nom_porteur': 'Lonjon',
#     'prenom_porteur': 'Michel',
#     'financement_total': 566218.0,
#     'numero_registre_essais': 'NCT03766087',
#     'numero_tranche': '2'}]},
#  'NCT04036643': {'financement_total': 275082.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'RECARHIA',
#     'titre': "Apport de la [18F]-FDG-TEP/IRM dans la détection de l'absence de  réponse complète après radiochiomiothérapie néo-adjuvante pour les cancers du moyen et du bas rectum en vue d'une procédure de traitement avec épargne rectale",
#     'discipline_principale': 'autre',
#     'nom_porteur': 'LUCIDARME',
#     'prenom_porteur': 'Olivier',
#     'financement_total': 275082.0,
#     'numero_registre_essais': 'NCT04036643',
#     'numero_tranche': '2'}]},
#  'NCT03920722': {'financement_total': 937579.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'RITUXGOPRO',
#     'titre': 'Efficacité et tolérance du rituximab dans le traitement des polyangéites microscopiques de bon pronostic',
#     'discipline_principale': 'médecine interne',
#     'nom_porteur': 'Regent',
#     'prenom_porteur': 'Alexis',
#     'financement_total': 937579.0,
#     'numero_registre_essais': 'NCT03920722',
#     'numero_tranche': '2'}]},
#  'NCT03667365': {'financement_total': 986944.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Bretagne',
#     'nom_etablissement': 'CHRU RENNES',
#     'finess': 350005179,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'ROTAS',
#     'titre': "Etude randomisée pour une prise en charge optimale des patients ayant un Rétrécissement Valvulaire Aortique à Bas gradient et Fraction ventriculaire d'Ejection Préservée",
#     'discipline_principale': 'cardiologie',
#     'nom_porteur': 'Galli',
#     'prenom_porteur': 'Elena',
#     'financement_total': 986944.0,
#     'numero_registre_essais': 'NCT03667365',
#     'numero_tranche': '2'}]},
#  'NCT03716921': {'financement_total': 807077.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Île-de-France',
#     'nom_etablissement': 'ASSISTANCE PUBLIQUE-HOPITAUX DE PARIS',
#     'finess': 750712184,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'SHASAR',
#     'titre': "Traitement antibiotique court de trois semaines versus six semaines dans les arthrites septiques sans matériel de l'adulte : essai randomisé ouvert de non infériorité",
#     'discipline_principale': 'rhumatologie',
#     'nom_porteur': 'Escaut',
#     'prenom_porteur': 'Lelia',
#     'financement_total': 807077.0,
#     'numero_registre_essais': 'NCT03716921',
#     'numero_tranche': '3'}]},
#  'NCT05098704': {'financement_total': 299613.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Nouvelle-Aquitaine',
#     'nom_etablissement': 'CHU DE BORDEAUX',
#     'finess': 330781196,
#     'type_etablissement': 'CH',
#     'acronyme': 'PSSIT',
#     'titre': "Essai clinique de phase II/III randomisé en double aveugle versus placebo évaluant l'efficacité d'un traitement Préventif par Clopidogrel sur le risque d'évolution vers une Sclérodermie Systémique chez des sujets présentant une association dysImmuniTé spécifique/phénomène de Raynaud",
#     'discipline_principale': 'rhumatologie immunologie',
#     'nom_porteur': 'TRUCHETET',
#     'prenom_porteur': 'Marie-Elise',
#     'financement_total': 299613.0,
#     'numero_registre_essais': 'NCT05098704',
#     'numero_tranche': '3'}]},
#  'NCT03690518': {'financement_total': 263370.0,
#   'financements': [{'appel_a_projets': 'PHRCI',
#     'annee_de_selection': 2017,
#     'region': 'Occitanie',
#     'nom_etablissement': 'CHU MONTPELLIER',
#     'finess': 340780477,
#     'type_etablissement': 'CH',
#     'acronyme': 'REHAB CHD',
#     'titre': 'Impact de la réhabilitation cardiovasculaire sur la qualité de vie des enfants et adultes porteurs de cardiopathies congénitales : essai multicentrique randomisé contrôlé',
#     'discipline_principale': 'cardiologie pédiatrique et congénitale, réhabilitation, essais cliniques',
#     'nom_porteur': 'GUILLAUMONT',
#     'prenom_porteur': 'Sophie',
#     'financement_total': 263370.0,
#     'numero_registre_essais': 'NCT03690518',
#     'numero_tranche': '3'}]},
#  'NCT03610256': {'financement_total': 621088.0,
#   'financements': [{'appel_a_projets': 'PHRCN',
#     'annee_de_selection': 2017,
#     'region': 'Auvergne-Rhône-Alpes',
#     'nom_etablissement': 'HOSPICES CIVILS DE LYON',
#     'finess': 690781810,
#     'type_etablissement': 'CHUR',
#     'acronyme': 'SADISLEEVE',
#     'titre': "Etude prospective, multicentrique, randomisée, contrôlée de l'efficacité et de la sécurité du Bypass duodéno iléal avec sleeve gastrectomy (Single Anastomosis Duodéno Iléal bypass with sleeve gastrectomy (SADI-S)) versus Bypass gastrique Roux-en-Y (RYGB)",
#     'discipline_principale': 'chirurgie viscérale et digestive',
#     'nom_porteur': 'Robert',
#     'prenom_porteur': 'Maud',
#     'financement_total': 621088.0,
#     'numero_registre_essais': 'NCT03610256',
#     'numero_tranche': '3'}]},
#  ...}
